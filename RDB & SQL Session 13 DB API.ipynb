# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [What is API?](#1)
# * [PyODBC](#2)
# * [Connect to SQL Server](#3)
#     * [1. Windows Authentication](#3.1)
#     * [2. SQL Server Authentication](#3.2)
# * [Cursor Operations](#4)
#     * [1. Execute](#4.1)
#     * [2. Fetchone](#4.2)
#     * [3. Fetchmany](#4.3)
#     * [4. Fetchall](#4.4)
# * [How to Create a Dataframe from a query result?](#5)
#     * [1. pd.dataframe](#5.1)
#     * [2. pd.read_sql](#5.2)
# * [How to transfer a dataframe to SQL Server?](#6)
#     * [1. Using PyODBC](#6.1)
#     * [2. Using SQLAlchemy](#6.2)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">What is API?</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>An <font color=red>API</font>, or <font color=red>Application Programming Interface</font>, is a set of rules and protocols that allows different software applications to communicate and interact with each other. It defines the methods and data formats applications can use to request and exchange information, enabling them to work together seamlessly. APIs play a crucial role in enabling the integration of services, data, and functionalities across various software systems.</font>

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">PyODBC</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue><font color=red>PyODBC</font> is a Python module that enables you to connect and interact with relational databases, such as Microsoft SQL Server, using the <font color=red>Open Database Connectivity (ODBC)</font> standard. It provides a convenient way to perform database operations in Python, including querying, inserting, updating, and deleting data, making it a valuable tool for working with databases in Python applications.</font>

# %%
#pip install pyodbc

# %%
import pyodbc

# %% [markdown]
# **!! On Mac,**,  if you do not already have an ODBC driver manager, you may need to first install unixODBC using a tool like Homebrew.
#
# `brew install unixodbc`
# <br>`pip install pyodbc`

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Connect to SQL Server</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
help(pyodbc.connect)

# Accepts an ODBC connection string and returns a new Connection object.
# Out:
# Help on built-in function connect in module pyodbc:
#
# connect(...)
#     connect(str, autocommit=False, ansi=False, timeout=0, **kwargs) --> Connection
#
#     Accepts an ODBC connection string and returns a new Connection object.
#
#     The connection string will be passed to SQLDriverConnect, so a DSN connection
#     can be created using:
#
#       cnxn = pyodbc.connect('DSN=DataSourceName;UID=user;PWD=password')
#
#     To connect without requiring a DSN, specify the driver and connection
#     information:
#
#       DRIVER={SQL Server};SERVER=localhost;DATABASE=testdb;UID=user;PWD=password
#
#     Note the use of braces when a value contains spaces.  Refer to SQLDriverConnect
#     documentation or the documentation of your ODBC driver for details.
#
#     The connection string can be passed as the string `str`, as a list of keywords,
#     or a combination of the two.  Any keywords except autocommit, ansi, and timeout
#     (see below) are simply added to the connection string.
#
#       connect('server=localhost;user=me')
#       connect(server='localhost', user='me')
#       connect('server=localhost', user='me')
#
#     The DB API recommends the keywords 'user', 'password', and 'host', but these
#     are not valid ODBC keywords, so these will be converted to 'uid', 'pwd', and
#     'server'.
#
#     Special Keywords
#
#     The following specal keywords are processed by pyodbc and are not added to the
#     connection string.  (If you must use these in your connection string, pass them
#     as a string, not as keywords.)
#
#       autocommit
#         If False or zero, the default, transactions are created automatically as
#         defined in the DB API 2.  If True or non-zero, the connection is put into
#         ODBC autocommit mode and statements are committed automatically.
#
#       ansi
#         By default, pyodbc first attempts to connect using the Unicode version of
#         SQLDriverConnectW.  If the driver returns IM001 indicating it does not
#         support the Unicode version, the ANSI version is tried.  Any other SQLSTATE
#         is turned into an exception.  Setting ansi to true skips the Unicode
#         attempt and only connects using the ANSI version.  This is useful for
#         drivers that return the wrong SQLSTATE (or if pyodbc is out of date and
#         should support other SQLSTATEs).
#
#       timeout
#         An integer login timeout in seconds, used to set the SQL_ATTR_LOGIN_TIMEOUT
#         attribute of the connection.  The default is 0 which means the database's
#         default timeout, if any, is used.

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'SQL Server Native Client RDA 11.0',
#  'SQL Server Native Client 11.0',
#  'ODBC Driver 17 for SQL Server']

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Windows Authentication</p>
#
# <a id="3.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
conn_string = "driver={ODBC Driver 17 for SQL Server}; server=localhost; database=master; TRUSTED_CONNECTION=yes;"

# %%
conn = pyodbc.connect(conn_string)

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">SQL Server Authentication</p>
#
# <a id="3.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
driver = '{ODBC Driver 17 for SQL Server}'
server = 'localhost'
database = 'master'
user = 'sa'
password = '----'

# %%
conn = pyodbc.connect(DRIVER = driver, SERVER= server, DATABASE = database, UID= user, PWD= password)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Cursor Operations</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>A cursor is a database object or programming construct used in database management systems (DBMS). It acts as a pointer to a specific row within a result set from a database query. Cursors are commonly used in programming languages like Python to navigate and manipulate data retrieved from a database, allowing for actions such as fetching, updating, and deleting records in a systematic manner.</font>

# %% [markdown]
# Help on built-in function cursor:
#
# cursor(...) method of pyodbc.Connection instance
#     Return a new Cursor object using the connection.

# %%
crs = conn.cursor()

# %%
type(crs)
# Out:
# pyodbc.Cursor

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Execute</p>
#
# <a id="4.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
conn.autocommit = True

# %%
crs.execute('create DATABASE TestA')

# %%
crs.execute('USE TestA')

# %%
def execute_query(conn, query):
    crs = conn.cursor()
    try:
        crs.execute(query)
        conn.commit()
        print("Query Succeessful!")
    except Error as err:
        print(f"Error:'{err}'")

# %%
query = 'CREATE TABLE TestTable (\
           ID INT IDENTITY (1,1) NOT NULL, \
           FirstName VARCHAR(255) NOT NULL,\
           LastName VARCHAR(255) NOT NULL,\
           PRIMARY KEY(ID))'

# %%
execute_query(conn, query)
# Out:
# Query Succeessful!

# %%
crs.execute("INSERT TestTable (FirstName, LastName) VALUES ('Bob', 'Marley')")

# %%
crs.execute("INSERT TestTable (FirstName, LastName) VALUES (?,?)",'Tom', 'Cat')
crs.execute("INSERT TestTable (FirstName, LastName) VALUES (?,?)",'Jerry', 'Mouse')
crs.execute("INSERT TestTable (FirstName, LastName) VALUES (?,?)",'Owen', 'William')
crs.execute("INSERT TestTable (FirstName, LastName) VALUES (?,?)",'Stefan', 'Müller')

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Fetchone</p>
#
# <a id="4.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>Retrieves the next row of a query result set as a tuple or None if there are no more rows to fetch.</font>

# %%
crs.execute('SELECT FirstName, LastName FROM TestTable')

# %%
crs.fetchone()

# %%
crs.execute('SELECT ID, FirstName, LastName FROM TestTable')
rows = crs.fetchone()
rows

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Fetchmany</p>
#
# <a id="4.3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>Retrieves a specified number of rows from a query result set, returning them as a list of tuples.</font>

# %%
crs.execute("""SELECT ID, FirstName, LastName 
               FROM TestTable""")
rows = crs.fetchmany(3)
rows
# Out:
# [(1, 'Bob', 'Marley'), (2, 'Tom', 'Cat'), (3, 'Jerry', 'Mouse')]

# %%
crs.fetchmany(3)

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Fetchall</p>
#
# <a id="4.4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>Retrieves all the remaining rows from a query result set and returns them as a list of tuples.</font>

# %%
crs.execute('SELECT ID, FirstName, LastName FROM TestTable')
rows = crs.fetchall()
rows

# %%
for row in rows:
    print(row.ID, row.FirstName, row.LastName)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Create a Dataframe from a query result?</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
#pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">pd.Dataframe</p>
#
# <a id="5.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
crs.execute('SELECT * FROM TestTable')
result = crs.fetchall()
result
# Out:
# [(1, 'Bob', 'Marley'),
#  (2, 'Tom', 'Cat'),
#  (3, 'Jerry', 'Mouse'),
#  (4, 'Owen', 'William'),
#  (5, 'Stefan', 'Müller')]

# %%
df = pd.DataFrame(result)
df
# Out:
#                      0
# 0     [1, Bob, Marley]
# 1        [2, Tom, Cat]
# 2    [3, Jerry, Mouse]
# 3   [4, Owen, William]
# 4  [5, Stefan, Müller]

# %%
from_db = []

for result in result:
    result = list(result)
    from_db.append(result)

# %%
from_db
# Out:
# [[1, 'Bob', 'Marley'],
#  [2, 'Tom', 'Cat'],
#  [3, 'Jerry', 'Mouse'],
#  [4, 'Owen', 'William'],
#  [5, 'Stefan', 'Müller']]

# %%
columns = ['ID','FirstName', 'LastName']
df = pd.DataFrame(from_db, columns = columns)
df
# Out:
#    ID FirstName LastName
# 0   1       Bob   Marley
# 1   2       Tom      Cat
# 2   3     Jerry    Mouse
# 3   4      Owen  William
# 4   5    Stefan   Müller

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">pd.read_sql</p>
#
# <a id="5.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
query = 'USE SampleRetail'
execute_query(conn,query)
# Out:
# Query Succeessful!

# %%
crs.execute("SELECT * FROM product.product").fetchall()
# Out:
# [(1, 'DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 1710 1715 1730 1735 1750 1755 1955 3000 3005 A100 M30X M35X - Black', 23, 4, 2021, Decimal('23.99')),
#  (2, 'NS-SP1800BL 5.1-Channel Home Theater System (Black)', 5, 5, 2021, Decimal('136.99')),
#  (3, 'Acoustimass 6 Series V Home Theater Speaker System (Black)', 24, 5, 2021, Decimal('599.00')),
#  (4, 'Corsair Vengeance LPX 16GB (2x8GB) DDR4 DRAM 3000MHz C15 Desktop Memory Kit - Black (CMK16GX4M2B3000C15)', 6, 4, 2021, Decimal('151.99')),
#  (5, 'Details About Samsung Gear Iconx 2018 Edition Cordfree Fitness Earbuds Black (us Version)', 1, 14, 2021, Decimal('199.99')),
#  (6, '2TB Red 5400 rpm SATA III 3.5 Internal NAS HDD', 12, 4, 2021, Decimal('89.95')),
#  (7, 'Details About Alpine 480w 6.5 2way Typee Coaxial Car Speakers W/ Silk Tweeters | Spe6000"', 35, 5, 2021, Decimal('59.99')),
#  (8, 'Kenwood KFC-1653MRW 6.5 2-way Marine Speakers Pair (White)"', 31, 5, 2021, Decimal('99.99')),
#  (9, 'Microsoft Surface Pro 4 Type Cover with Fingerprint ID', 16, 4, 2021, Decimal('121.99')),
#  (10, 'CORSAIR VENGEANCE RGB 16GB (2x8GB) DDR4 3200MHz C16 Desktop Memory - Black', 6, 4, 2021, Decimal('174.99')),
#  (11, 'DENAQ - AC Power Adapter and Charger for Select HP Omnibook, Pavilion and Presario Laptops - Black', 23, 4, 2021, Decimal('29.99')),
#  (12, 'Samsung - 50 Class (49.5" Diag.) - LED - 1080p - Smart - HDTV"', 1, 1, 2021, Decimal('499.99')),
#  (13, 'Polk Audio - 50 W Woofer - Black', 21, 5, 2021, Decimal('99.99')),
#  (14, 'Apple - Pre-Owned iPad 3 - 64GB - Black', 2, 4, 2021, Decimal('249.99')),
#  (15, 'Corsair CMSA8GX3M2A1066C7 Apple 8 GB Dual Channel Kit DDR3 1066 (PC3 8500) 204-Pin DDR3 Laptop SO-DIMM Memory 1.5V', 6, 4, 2021, Decimal('67.99')),
#  (16, 'Virtually Invisible 891 In-Wall Speakers (Pair)', 24, 5, 2021, Decimal('599.00')),
#  (17, 'DENAQ - AC Power Adapter and Charger for Select Toshiba Satellite and Satellite Pro Laptops - Black', 23, 4, 2021, Decimal('11.99')),
#  (18, 'Lenovo - AC Adapter for Select Lenovo Yoga Laptops - Black', 13, 4, 2021, Decimal('24.99')),
#  (19, 'Sony - SRS-XB21 Portable Bluetooth Speaker - Black', 3, 5, 2021, Decimal('99.99')),
#  (20, 'Russound - Acclaim 5 Series 6-1/2 Indoor/Outdoor Speaker (Each) - White"', 29, 5, 2021, Decimal('249.99')),
#  (21, 'SB-2000 12 500W Subwoofer (Piano Gloss Black)', 36, 5, 2021, Decimal('799.98')),
#  (22, 'Kenwood - Road Series 6 x 8" 2-Way Car Speakers with Paper Woofer Cones (Pair) - Black"', 31, 5, 2021, Decimal('23.99')),
#  (23, '4TB Red 5400 rpm SATA III 3.5 Internal NAS HDD Retail Kit', 12, 4, 2021, Decimal('149.99')),
#  (24, "AudioQuest - Golden Gate 9.8' RCA-to-RCA Audio Cable - Black/Red", 34, 13, 2021, Decimal('89.99')),
#  (25, 'Toshiba - 3TB Internal Serial ATA III Hard Drive for Desktops', 25, 4, 2021, Decimal('139.99')),
#  (26, 'Logitech - G560 LIGHTSYNC 2.1 Bluetooth Gaming Speakers with Game Driven RGB Lighting (3-Piece) - Black', 4, 4, 2021, Decimal('199.99')),
#  (27, 'Details About *brand New* Pny Anarchy 16gb Kit (2x8gb) Ddr4 2400mhz Pc419200 Desktop Memory', 18, 4, 2021, Decimal('98.95')),
#  (28, 'WI-SP500 Wireless In-Ear Sports Headphones (Black)', 3, 14, 2021, Decimal('79.99')),
#  (29, '251 Outdoor Environmental Speakers (White)', 24, 4, 2021, Decimal('398.00')),
#  (30, 'Sony Mini Digital Video Cassettes - DVC - 1 Hour', 3, 4, 2021, Decimal('11.79')),
#  (31, 'Russound - Acclaim 5 Series 5-1/4 2-Way Indoor/Outdoor Speakers (Pair) - White"', 29, 5, 2021, Decimal('142.99')),
#  (32, 'Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charcoal black', 3, 5, 2021, Decimal('74.99')),
#  (33, 'Circle 2 2MP Wire-Free Network Camera with Night Vision', 4, 13, 2021, Decimal('199.99')),
#  (34, 'Samsung-3-Pack-Connect-Home-Smart-Wi-Fi-System-AC1300', 1, 4, 2021, Decimal('239.00')),
#  (35, 'SRS-ZR7 Wireless Speaker', 3, 5, 2021, Decimal('248.00')),
#  (36, 'SanDisk Extreme 500 Portable SSD 500GB SDSSDEXT-500G-G25', 9, 4, 2021, Decimal('199.99')),
#  (37, 'VE278Q 27 Widescreen LCD Computer Display', 10, 4, 2021, Decimal('199.99')),
#  (38, '1TB T5 Portable Solid-State Drive (Black)', 1, 4, 2021, Decimal('349.99')),
#  (39, 'SRS-XB40 Bluetooth Speaker (Black)', 3, 5, 2021, Decimal('148.00')),
#  (40, 'WD - My Passport X 3TB External USB 3.0 Portable Hard Drive - Black', 12, 4, 2021, Decimal('99.99')),
#  (41, 'Dell - P2418HT 24 IPS LED FHD Touch-Screen Monitor - Black"', 19, 4, 2021, Decimal('323.52')),
#  (42, 'Toshiba - 2.0-Channel Soundbar with 16-Watt Digital Amplifier - Black', 25, 5, 2021, Decimal('99.99')),
#  (43, 'AudioQuest - GOLDG01R Golden Gate 1m (3.28 ft.) RCA Audio Cable - Red', 34, 13, 2021, Decimal('68.75')),
#  (44, 'Lenovo - 300-20ISH 20 All-In-One - Intel Pentium - 4GB Memory - 500GB Hard Drive - Black"', 13, 4, 2021, Decimal('449.99')),
#  (45, 'XPS 8920 Tower Desktop Computer', 19, 4, 2021, Decimal('919.99')),
#  (46, 'Leviathan Elite Gaming Soundbar', 11, 4, 2021, Decimal('195.99')),
#  (47, 'UBD-M9500 HDR UHD Upscaling Blu-ray Disc Player', 1, 1, 2021, Decimal('399.98')),
#  (48, 'Sharp - 350W 5-Disc Mini Component System - Black', 32, 5, 2021, Decimal('299.87')),
#  (49, 'Details About Netgear Nighthawk A7000 (ac1900) Dualband Wifi Usb Adapter', 8, 4, 2021, Decimal('65.89')),
#  (50, 'TP-Link AV500 2-port Powerline Starter Kit', 26, 4, 2021, Decimal('34.99')),
#  (51, 'CORSAIR - VOID Surround Hybrid Wired Stereo Gaming Headset for PC, PS4, Xbox One, Nintendo Switch, Mobile devices - Carbon', 6, 4, 2021, Decimal('79.99')),
#  (52, 'Everest Elite 700 Around-Ear Wireless Headphones (White)', 7, 14, 2021, Decimal('224.99')),
#  (53, 'AW6500 All-Weather Outdoor Speaker (White, Single)', 33, 5, 2021, Decimal('249.98')),
#  (54, 'Sony LBT-GPX555 Mini-System with Bluetooth and NFC', 3, 7, 2021, Decimal('324.99')),
#  (55, 'Toshiba Micro Component Speaker System: Wireless Bluetooth Speaker Sound System with FM', 25, 7, 2021, Decimal('89.99')),
#  (56, 'Prime Three-Way Center Channel Speaker (Premium Black Ash)', 36, 5, 2021, Decimal('349.99')),
#  (57, 'CORSAIR - AX760 760-Watt ATX Power Supply - Black', 6, 4, 2021, Decimal('179.99')),
#  (58, 'Samsung - 960 Pro 1TB Internal PCI Express 3.0 x4 (NVMe 1.1) Solid State Drive', 1, 4, 2021, Decimal('617.99')),
#  (59, 'Klipsch - Reference Soundbar with 10 Wireless Subwoofer - Black"', 27, 5, 2021, Decimal('799.99')),
#  (60, 'Details About Microsoft Arc Mouse Bluetooth 4.0 Souris Wireless For Surface Windows 10', 16, 4, 2021, Decimal('79.99')),
#  (61, 'DENAQ - 8-Cell Lithium-Ion Battery for Select HP Pavilion Laptops', 23, 4, 2021, Decimal('82.99')),
#  (62, 'The Rebel BT On-Ear Wireless Bluetooth Headphones (Black)', 20, 14, 2021, Decimal('39.99')),
#  (63, 'NETGEAR AC1000 Dual Band Smart WiFi Router', 8, 4, 2021, Decimal('54.99')),
#  (64, 'LG - 75 Class - LED - UJ6470 Series - 2160p - Smart - 4K UHD TV with HDR"', 15, 1, 2021, Decimal('2299.99')),
#  (65, 'Apple - Pre-Owned iPad 3 - 32GB - White', 2, 4, 2021, Decimal('219.99')),
#  (66, 'Yamaha - MusicCast 5.1-Ch. 4K Ultra HD A/V Home Theater Receiver - Black', 5, 16, 2021, Decimal('599.95')),
#  (67, 'SVS - Prime Dual 5-1/4 Passive 3-Way Center-Channel Speaker - Gloss piano black"', 36, 5, 2021, Decimal('449.98')),
#  (68, 'Lenovo - 510-23ISH 23 Touch-Screen All-In-One - Intel Core i5 - 8GB Memory - 2TB Hard Drive - Black"', 13, 4, 2021, Decimal('849.99')),
#  (69, 'Alpine - 6 x 9" 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black"', 35, 5, 2021, Decimal('54.99')),
#  (70, 'NS-IW480CWH In-Ceiling 8 Natural Sound Three-Way Speaker System (Pair)', 5, 5, 2021, Decimal('124.95')),
#  (71, 'Logitech Ultrathin Touch Mouse T630 for Windows 8 Touch Gestures', 4, 4, 2021, Decimal('29.99')),
#  (72, 'Samsung Radiant360 R1 Wi-Fi/Bluetooth Speaker WAM1500/ZA - Black (Certified Refurbished)', 1, 5, 2021, Decimal('71.99')),
#  (73, 'Logitech Focus Case with Integrated Keyboard for iPad Mini 4, Dark Blue', 4, 4, 2021, Decimal('68.99')),
#  (74, '32GB High Speed UHS-I SDHC U3 Memory Card (Class 10)', 3, 4, 2021, Decimal('33.79')),
#  (75, 'ProSafe 16-Port Gigabit Desktop Switch', 8, 4, 2021, Decimal('79.99')),
#  (76, 'WD - Se 2TB Internal Serial ATA Hard Drive for Desktops (OEM/Bare Drive)', 12, 4, 2021, Decimal('455.90')),
#  (77, 'TP-Link Archer T9E AC1900 Wireless WiFi PCIe network Adapter Card for PC', 26, 4, 2021, Decimal('69.99')),
#  (78, '151 SE Outdoor Environmental Speakers (White)', 24, 5, 2021, Decimal('278.00')),
#  (79, 'JBL Everest 710 Silver Over-Ear Wireless Bluetooth Headphones (Silver)', 7, 14, 2021, Decimal('249.99')),
#  (80, 'Acer - 2-in-1 15.6 Refurbished Touch-Screen Laptop - Intel Core i7 - 12GB Memory - NVIDIA GeForce 940MX - 1TB Hard Drive - Steel gray"', 38, 4, 2021, Decimal('809.99')),
#  (81, 'Samsung - 960 EVO 500GB Internal PCI Express 3.0 x4 (NVMe) Solid State Drive for Laptops', 1, 4, 2021, Decimal('234.59')),
#  (82, 'Acer Aspire E5-574-53QS 15.6 LED Notebook - Intel Core i5 (6th Gen) i5-6200U Dual-core (2 Core) 2.30 GHz - 4 GB DDR3L SDRAM RAM - 1 TB HDD - DVD-Writer - Intel HD Graphics 550 DDR3L SDRAM - Wind"', 38, 4, 2021, Decimal('389.99')),
#  (83, 'Logitech Circle Black Portable Wifi Video Monitoring Camera Webcam', 4, 4, 2018, Decimal('159.99')),
#  (84, 'Samsung - 850 PRO 1TB Internal SATA III Solid State Drive for Laptops', 1, 4, 2018, Decimal('479.99')),
#  (85, 'Samsung - 40 Class (39.5" Diag.) - LED - 1080p - Smart - HDTV"', 1, 1, 2018, Decimal('397.99')),
#  (86, 'Details About Razer Kraken Pro V2 Analog Gaming Headset For Pc/xbox One/ps4 Black (p05)', 11, 4, 2018, Decimal('52.95')),
#  (87, 'Alpine - 6-1/2 2-Way Component Car Speakers with Poly-Mica Cones (Pair) - Black"', 35, 5, 2018, Decimal('100.99')),
#  (88, 'SanDisk - Ultra 500GB Internal SATA Solid State Drive for Laptops', 9, 4, 2018, Decimal('199.99')),
#  (89, 'Definitive Technology - Disappearing Dual 6-1/2 In-Wall Speaker (Each) - Black"', 33, 5, 2018, Decimal('549.99')),
#  (90, 'Razer - Blade Pro 17.3 4K Ultra HD Touch-Screen Laptop - Intel Core i7 - 32GB Memory - NVIDIA GeForce GTX 1080 - 1TB SSD - Black"', 11, 4, 2018, Decimal('3989.99')),
#  (91, 'Sennheiser - Earbud Headphones - Black', 30, 11, 2018, Decimal('799.98')),
#  (92, 'Sony - WH-CH700N Wireless Noise Canceling Over-the-Ear Headphones - Black', 3, 14, 2018, Decimal('199.99')),
#  (93, 'Logitech iPad Pro 12.9 inch Keyboard Case SLIM COMBO with Detachable', 4, 4, 2018, Decimal('118.99')),
#  (94, '128GB iPod touch (Space Gray) (6th Generation)', 2, 6, 2018, Decimal('349.99')),
#  (95, 'Apple iPod Touch 128GB Blue', 2, 6, 2018, Decimal('349.99')),
#  (96, 'Logitech - Harmony Home Hub - Black', 4, 13, 2018, Decimal('99.99')),
#  (97, 'Razer BlackShark Over Ear Noise Isolating PC Gaming Headset - Metal Construction and Compatible with PS4', 11, 4, 2018, Decimal('112.99')),
#  (98, 'DENAQ - AC Power Adapter and Charger for Select Dell Inspiron and Latitude Laptops - Black', 23, 4, 2018, Decimal('20.99')),
#  (99, 'MCR-B043 30W Bluetooth Wireless Music System (Red)', 5, 10, 2018, Decimal('249.99')),
#  (100, 'Pro-Series 49-Class Full HD Outdoor LED TV (Silver)', 22, 1, 2018, Decimal('4295.98')),
#  (101, 'HD 4.40 BT Wireless Bluetooth Headphones', 30, 14, 2018, Decimal('149.95')),
#  (102, 'Yamaha - Micro Component System - Blue', 5, 10, 2018, Decimal('264.99')),
#  (103, 'Details About Netgear 16 X 4 Docsis 3.0 Cable Modem Black', 8, 4, 2018, Decimal('129.99')),
#  (104, 'Sony - High Power XB60 Portable Bluetooth Speaker - Black', 3, 5, 2018, Decimal('349.99')),
#  (105, 'Under Armour Sport Wireless Flex Neckband In-Ear Headphones', 7, 14, 2018, Decimal('129.95')),
#  (106, 'Lenovo Flex 4 1470 80SA0000US 2-in-1 - 14 HD Touch - Pentium 4405U 2.1Ghz - 4GB - 500GB"', 13, 4, 2018, Decimal('303.99')),
#  (107, 'PNY Performance 8GB Kit (2x4GB) DDR3 1600MHz (PC3-12800) CL11 Desktop Memory - MD8GK2D31600NHS-Z', 18, 4, 2018, Decimal('47.95')),
#  (108, 'DENAQ - AC Power Adapter and Charger for Select Toshiba Satellite Laptops - Black', 23, 4, 2018, Decimal('27.99')),
#  (109, 'CORSAIR - MM800 Polaris RGB Gaming Mouse Pad - Black', 6, 4, 2018, Decimal('49.99')),
#  (110, 'Lenovo Yoga Mouse', 13, 4, 2018, Decimal('54.99')),
#  (111, "AudioQuest - Black Lab 16.4' In-Wall Subwoofer Cable - Black/White", 34, 13, 2018, Decimal('49.99')),
#  (112, 'JBL Under Armour Sport Wireless Heart Rate In-Ear Headphones Black', 7, 11, 2018, Decimal('199.99')),
#  (113, 'JBL - Free True Wireless In-Ear Headphones - Black', 7, 14, 2018, Decimal('129.95')),
#  (114, 'Pioneer - Elite 7.2-Ch. Hi-Res 4K Ultra HD HDR Compatible A/V Home Theater Receiver - Black', 17, 16, 2018, Decimal('499.00')),
#  (115, 'SunBriteTV - Outdoor Tilting TV Wall Mount for Most 37 - 80" TVs - Powder coated black"', 22, 13, 2018, Decimal('149.98')),
#  (116, 'My Cloud Expert Series EX4100 24TB 4-Bay NAS Server (4 x 6TB)', 12, 4, 2018, Decimal('1449.00')),
#  (117, 'CORSAIR - VENGEANCE RGB Series 32GB (4PK 8GB) 3.466GHz DDR4 Desktop Memory with RGB Lighting - Black', 6, 4, 2018, Decimal('359.99')),
#  (118, 'Marantz - SR 9.2-Ch. Hi-Res With HEOS 4K Ultra HD A/V Home Theater Receiver - Black', 28, 16, 2018, Decimal('2199.98')),
#  (119, 'Yamaha - Natural Sound 5 2-Way All-Weather Outdoor Speakers (Pair) - White"', 5, 5, 2018, Decimal('87.99')),
#  (120, 'GTK-XB90 Bluetooth Speaker', 3, 5, 2018, Decimal('449.99')),
#  (121, 'RX-V583 7.2-Channel Network A/V Receiver', 5, 7, 2018, Decimal('429.99')),
#  (122, 'Kenwood CD Single DIN In-Dash Bluetooth Car Stereo Receiver KDC-BT365U', 31, 15, 2018, Decimal('83.99')),
#  (123, 'SP-C22 Andrew Jones Designed Center Channel Speaker', 17, 5, 2018, Decimal('99.99')),
#  (124, 'MU8000-Series 65-Class HDR UHD Smart LED TV', 1, 1, 2018, Decimal('1597.99')),
#  (125, 'CORSAIR - HD Series 120mm Case Cooling Fan Kit with RGB lighting', 6, 4, 2018, Decimal('76.99')),
#  (126, 'Samsung - 960 PRO 512GB Internal PCI Express 3.0 x4 (NVMe) Solid State Drive for Laptops', 1, 4, 2018, Decimal('329.99')),
#  (127, 'JBL Inspire 700 In-Ear Wireless Sport Headphones with Charging Case (Black)', 7, 14, 2018, Decimal('54.00')),
#  (128, 'NETGEAR Nighthawk AC1900 VDSL/ADSL Modem Router Certified with CenturyLink - Non-bonded', 8, 4, 2018, Decimal('249.99')),
#  (129, 'CORSAIR - VENGEANCE LED Series 16GB (2PK 8GB) 3.0GHz DDR4 Desktop Memory with LED Lighting - Black', 6, 4, 2018, Decimal('203.99')),
#  (130, 'Alpine Electronics PWE-S8-WRA Powered Subwoofer for 2011-Up Jeep Wrangler', 35, 8, 2018, Decimal('499.95')),
#  (131, 'HP 15-AY103DX 15.6 Touchscreen Touch Screen HD Laptop Notebook PC Computer 7th Gen i5-7200U Kaby Lake 8GB Memory 1TB HDD Hard Drive Windows 10"', 39, 4, 2018, Decimal('429.99')),
#  (132, 'Apple MD825AM/A Lightning to VGA Adapter for iPhones', 2, 4, 2018, Decimal('48.99')),
#  (133, 'Sony - 55 Class - OLED - A1E Series - 2160p - Smart - 4K UHD TV with HDR"', 3, 1, 2018, Decimal('2998.00')),
#  (134, 'CORSAIR - Vengeance Pro Series 16GB (2PK x 8GB) 1.6 GHz DDR3 DIMM Desktop Memory Kit - Multi', 6, 4, 2018, Decimal('149.99')),
#  (135, 'Logitech - Harmony 950 Universal Remote - Black', 4, 13, 2018, Decimal('199.99')),
#  (136, 'Details About Razer Cynosa Chroma Rgb Gaming Keyboard Spillresistant Durable Design', 11, 4, 2018, Decimal('58.99')),
#  (137, 'Logitech - Harmony 665 10-Device Universal Remote - Black', 4, 13, 2018, Decimal('49.99')),
#  (138, 'Details About Razer Blade Laptop 14 Full Hd (i77700hq"', 11, 4, 2018, Decimal('1269.99')),
#  (139, 'CORSAIR - Vengeance 16 GB (2PK x 8GB) 1.6 GHz DDR3 DIMM Desktop Memory Kit - Multi', 6, 4, 2018, Decimal('169.00')),
#  (140, '12 MacBook (Mid 2017, Gold)', 2, 4, 2018, Decimal('1503.99')),
#  (141, 'Seagate Backup Plus Ultra Slim 2TB Portable External Hard Drive', 14, 4, 2018, Decimal('98.99')),
#  (142, 'Yamaha - AVENTAGE 7.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black', 5, 16, 2018, Decimal('439.99')),
#  (143, 'CORSAIR - Vengeance LPX 32GB (2PK x 16GB) 2.6 GHz DDR4 DRAM Desktop Memory Kit - Black', 6, 4, 2018, Decimal('284.99')),
#  (144, 'Dell - XPS 2-in-1 13.3 Touch-Screen Laptop - Intel Core i7 - 16GB Memory - 256GB Solid State Drive - Silver"', 19, 4, 2018, Decimal('979.99')),
#  (145, 'Klipsch AW-4i In-Ear Headphones', 27, 11, 2018, Decimal('59.00')),
#  (146, 'Russound - Acclaim 5 Series 6-1/2 2-Way Indoor/Outdoor Speakers (Pair) - White"', 29, 5, 2018, Decimal('116.64')),
#  (147, 'LG - 65 Class - LED - SJ8500 Series - 2160p - Smart - 4K UHD TV with HDR"', 15, 1, 2018, Decimal('1599.52')),
#  (148, 'Seagate - Backup Plus 5TB External USB 3.0 Portable Hard Drive - silver', 14, 4, 2018, Decimal('139.99')),
#  (149, 'ASUS VivoBook Max X541SA 15.6Inch Laptop Intel Pentium 4GB Memory 500GB HD Matte IMR X541SA-PD0703X', 10, 4, 2018, Decimal('229.99')),
#  (150, 'Sharp - 5-Disc Micro System - Black', 32, 5, 2018, Decimal('179.99')),
#  (151, 'Apple - Pre-Owned iPad mini 4 - 16GB - Space gray', 2, 4, 2018, Decimal('319.99')),
#  (152, 'Corsair CMY32GX3M4A1600C9 Vengeance Pro 32GB (4x8GB) DDR3 1600 MHz (PC3 12800) Desktop 1.5V', 6, 4, 2018, Decimal('234.99')),
#  (153, '1TB WD Black Mobile OEM Hard Drive (WD10JPLX)', 12, 4, 2018, Decimal('64.99')),
#  (154, 'SVS - 12 800W Powered Subwoofer - Black oak veneer"', 36, 5, 2018, Decimal('1399.98')),
#  (155, "AudioQuest - RJE Vodka 2.5' Ethernet Cable - Black/Blue", 34, 7, 2018, Decimal('249.99')),
#  (156, 'Details About Logitech Ue Roll 2 Wireless Portable Bluetooth Waterproof Speaker', 4, 5, 2018, Decimal('69.99')),
#  (157, 'JBL Flip 3 Splashproof Portable Bluetooth Speaker (Teal)', 7, 5, 2018, Decimal('459.98')),
#  (158, 'SRS-XB40 Bluetooth Speaker (Blue)', 3, 5, 2018, Decimal('110.99')),
#  (159, 'Samsung - 960 EVO 250GB Internal PCI Express 3.0 x4 (NVMe) Solid State Drive for Laptops', 1, 4, 2018, Decimal('117.60')),
#  (160, 'Lenovo - Yoga 710 2-in-1 11.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - 128GB Solid State Drive - Silver Tablet PC Notebook 80V6000PUS"', 13, 4, 2018, Decimal('573.99')),
#  (161, 'Veranda Series 55-Class UHD Outdoor LED TV', 22, 1, 2018, Decimal('1999.99')),
#  (162, 'JBL Everest 310 On-Ear Wireless Bluetooth Headphones (Gun Metal)', 7, 14, 2018, Decimal('179.99')),
#  (163, 'NETGEAR Nighthawk X10 AD7200 802.11ac/ad Quad-Stream WiFi Router', 8, 4, 2018, Decimal('390.99')),
#  (164, 'HT-XT2 170W 2.1-Channel TV Speaker Base (Black)', 3, 7, 2018, Decimal('81.99')),
#  (165, 'Lenovo - YOGA Wireless Optical Mouse - Black', 13, 4, 2018, Decimal('29.95')),
#  (166, 'AVENTAGE RX-A1070 7.2-Channel Network A/V Receiver', 5, 16, 2018, Decimal('1199.98')),
#  (167, "AudioQuest - Golden Gate 6.6' Analog RCA Cable - Red", 34, 13, 2018, Decimal('79.98')),
#  (168, 'MCR-B043 30W Bluetooth Wireless Music System (Black)', 5, 10, 2018, Decimal('232.99')),
#  (169, 'Signature Series 43-Class UHD Outdoor LED TV (Black)', 22, 1, 2018, Decimal('2799.99')),
#  (170, 'Disappearing Series DI 5.5S 2-Way Speaker (Single, 5.25 Driver)', 33, 5, 2018, Decimal('249.98')),
#  (171, 'SVS - 12 800W Powered Subwoofer - Gloss piano black"', 36, 5, 2018, Decimal('1399.98')),
#  (172, 'SanDisk - 120GB Internal SATA Solid State Drive for Laptops', 9, 4, 2018, Decimal('48.99')),
#  (173, 'Marantz - NR 250W 5.2-Ch. Hi-Res With HEOS 4K Ultra HD A/V Home Theater Receiver - Black', 28, 16, 2018, Decimal('549.00')),
#  (174, '64GB High Speed UHS-I SDXC U3 Memory Card (Class 10)', 3, 4, 2018, Decimal('51.99')),
#  (175, 'CORSAIR - ML Series 140mm Case Cooling Fan - White', 6, 4, 2018, Decimal('29.85')),
#  (176, 'Yamaha RX-V383BL 5.1-Channel 4K Ultra HD AV Receiver with Bluetooth', 5, 16, 2018, Decimal('234.99')),
#  (177, 'SanDisk Ultra II 500GB SATA III SSD - 2.5-Inch 7mm Height Solid State Drive - SDSSDHII-500G-G25', 9, 4, 2018, Decimal('155.47')),
#  (178, 'Crystal 460X RGB Mid-Tower Case', 6, 4, 2018, Decimal('199.99')),
#  (179, '128GB iPod touch (Gold) (6th Generation)', 2, 6, 2018, Decimal('359.99')),
#  (180, 'Refurbished Samsung Curved 65 4K (2160P) Smart QLED TV (2017 Model) + 1 Year Extended Warranty (QN65Q7CAMFXZA)"', 1, 1, 2018, Decimal('3137.95')),
#  (181, 'AS-5i Pro Sport Earphones (Blue)', 27, 11, 2018, Decimal('79.00')),
#  (182, 'WD 4TB My Cloud Home Personal Cloud Storage - WDBVXC0040HWT-NESN', 37, 4, 2018, Decimal('165.99')),
#  (183, 'Sony - WF 1000X True Wireless In-Ear Noise Canceling Headphones - Black', 3, 14, 2018, Decimal('178.00')),
#  (184, 'MU9000-Series 65-Class HDR UHD Smart LED TV', 1, 1, 2018, Decimal('1949.52')),
#  (185, 'Samsung 860 EVO 500GB 2.5 Inch SATA III Internal SSD (MZ-76E500B/AM)', 1, 4, 2018, Decimal('143.99')),
#  (186, 'XBR-X850E-Series 75-Class HDR UHD Smart LED TV', 3, 1, 2018, Decimal('2498.00')),
#  (187, 'CORSAIR - VENGEANCE Series 16GB (2PK 8GB) 2.4GHz DDR4 Laptop Memory - Black', 6, 4, 2018, Decimal('179.99')),
#  (188, 'Pioneer - Elite 7.2-Ch. Hi-Res 4K Ultra HD HDR Compatible A/V Home Theater Receiver - Black', 17, 16, 2018, Decimal('499.98')),
#  (189, "Razer ManO'War Wireless 7.1 Surround Sound Gaming Headset (Black) Man O War READ", 11, 4, 2018, Decimal('169.99')),
#  (190, '4TB Network OEM HDD Retail Kit (8-Pack, WD40EFRX, Red Drives)', 12, 4, 2018, Decimal('140.45')),
#  (191, 'CORSAIR - VOID PRO RGB Wireless Dolby 7.1-Channel Surround Sound Gaming Heads...', 6, 4, 2018, Decimal('99.99')),
#  (192, 'Get Up Stand Bluetooth Home Audio System', 20, 5, 2018, Decimal('249.99')),
#  (193, 'CORSAIR HYDRO SERIES H100i v2 AIO Liquid CPU Cooler', 6, 4, 2018, Decimal('138.19')),
#  (194, 'h.ear go Wireless Speaker (Viridian Blue)', 3, 5, 2018, Decimal('189.99')),
#  (195, 'Sony - SF-UY2 Series 64GB SDXC UHS-I Memory Card', 3, 4, 2018, Decimal('72.99')),
#  (196, 'Definitive Technology - SuperCube 4000 8 1200-Watt Powered Subwoofer - Black"', 33, 5, 2018, Decimal('799.98')),
#  (197, 'CORSAIR - VENGEANCE LED Series 16GB (2PK 8GB) 2.4GHz DDR4 Desktop Memory with LED Lighting - Black', 6, 4, 2018, Decimal('161.99')),
#  (198, 'Russound - Acclaim 5 Series 100W 2-Way Indoor/Outdoor Speakers (Pair) - Black', 29, 5, 2018, Decimal('199.99')),
#  (199, "AudioQuest - RJE Cinnamon 2.5' Ethernet Cable - Black/Red", 34, 4, 2018, Decimal('75.99')),
#  (200, 'Razer Naga Chroma MMO Gaming Mouse 12 Programmable Thumb Buttons 16000 DPI Wired', 11, 4, 2018, Decimal('58.99')),
#  (201, 'Details About Fits Chevy Silverado Pickup 19992006 Speaker Upgrade Pioneer Tsg1345r Tsg4620s', 17, 5, 2018, Decimal('33.49')),
#  (202, '480GB Extreme Pro Solid State Drive', 9, 4, 2018, Decimal('219.99')),
#  (203, 'JBL - 6-1/2 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black"', 7, 5, 2018, Decimal('79.99')),
#  (204, 'DENAQ - AC Adapter for SONY PCG Series', 23, 4, 2018, Decimal('23.99')),
#  (205, 'Definitive Technology - Mythos 2-way 175 W Speaker - Pack of 1 - Black', 33, 5, 2018, Decimal('399.00')),
#  (206, 'Details About Sony Kd43x720e 43inch 4k Ultra Hd Smart Led Tv (2017 Model) Kd43x720e', 3, 1, 2018, Decimal('598.00')),
#  (207, 'RE270K AC750 Wi-Fi Range Extender with Smart Plug', 26, 4, 2018, Decimal('69.98')),
#  (208, 'Details About Wd Red Pro 8tb Nas Desktop Hard Drive Intellipower 6 Gbs 128 Mb Cache Wd8001ffwx', 37, 4, 2018, Decimal('322.99')),
#  (209, 'Dell DW316 External USB Slim DVD R/W Optical Drive 429-AAUX', 19, 4, 2018, Decimal('43.96')),
#  (210, 'Details About Logitech G403 Prodigy Wireless Gaming Mouse', 4, 4, 2018, Decimal('99.99')),
#  (211, 'Marantz - NR 350W 7.2-Ch. Hi-Res With HEOS 4K Ultra HD A/V Home Theater Receiver - Black', 28, 7, 2018, Decimal('749.00')),
#  (212, '15.4 MacBook Pro with Touch Bar (Late 2016, Space Gray)', 2, 4, 2018, Decimal('2.00')),
#  (213, 'Toshiba - 2TB Internal SATA Hard Drive for Desktops', 25, 4, 2018, Decimal('83.31')),
#  (214, 'NETGEAR GS116E-200NAS / NETGEAR ProSafe Plus GS116Ev2 - Switch - unmanaged - 16 x 10/100/1000 - desktop', 8, 4, 2018, Decimal('159.99')),
#  (215, 'Details About Netgear Modem Vdsl/adsl Broadband High Speed Dsl Dm200 Verizon At&t Used!', 8, 4, 2018, Decimal('59.99')),
#  (216, 'Sharp - 50W Executive Hi-Fi Component System - Black', 32, 5, 2018, Decimal('149.99')),
#  (217, 'HP - Bluetooth Laser Mouse - Black', 18, 4, 2018, Decimal('22.06')),
#  (218, 'Samsung - Adaptive Fast Charging Wall Charger - White', 1, 4, 2018, Decimal('7.99')),
#  (219, 'Sennheiser CX 7.00BT Wireless In-Ear Headphone', 30, 14, 2018, Decimal('149.99')),
#  (220, 'JBL Reflect Contour 2 Wireless Sport In-Ear Headphones with Three-Button Remote and Microphone (Blue)', 7, 14, 2018, Decimal('99.99')),
#  (221, 'SanDisk Ultra II 1TB SATA III SSD - 2.5-Inch 7mm Height Solid State Drive - SDSSDHII-1T00-G25', 9, 4, 2018, Decimal('307.99')),
#  (222, 'Yamaha - AVENTAGE 7.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black', 5, 16, 2018, Decimal('899.98')),
#  (223, 'NS-PA40 5.1-Channel Speaker System (Black)', 5, 5, 2018, Decimal('349.99')),
#  (224, 'R-S300 Natural Sound Stereo Receiver', 5, 16, 2018, Decimal('271.99')),
#  (225, 'SanDisk - Extreme PRO 64GB SDXC UHS-II Memory Card', 9, 4, 2018, Decimal('199.99')),
#  (226, 'CORSAIR - Vengeance LPX 16GB (2PK x 8GB) 3.2 GHz DDR4 DRAM Desktop Memory Kit - Black', 6, 4, 2018, Decimal('169.99')),
#  (227, 'Definitive Technology - Wireless Audio Adapter - Black/Silver', 33, 5, 2018, Decimal('399.98')),
#  (228, 'Sharp Aquos N7000 65 Class 4K Ultra WiFi Smart LED HDTV"', 32, 1, 2018, Decimal('1250.59')),
#  (229, 'WD - My Book 6TB External USB 3.0 Hard Drive - Black', 37, 4, 2018, Decimal('169.99')),
#  (230, 'SAMSUNG 65 Class 4K (2160P) Ultra HD Smart QLED HDR TV QN65Q6FNAFXZA (2018 Model)"', 1, 1, 2018, Decimal('2197.99')),
#  (231, 'Bose SoundLink Color Bluetooth Speaker (Black)', 24, 5, 2018, Decimal('89.00')),
#  (232, 'Sennheiser - CX 3.00 Earbud Headphones - Red', 30, 11, 2018, Decimal('33.99')),
#  (233, 'Samsung - 49 Class (48.5" Diag.) - LED - 1080p - Smart - HDTV"', 1, 1, 2018, Decimal('431.99')),
#  (234, 'Lenovo - 100S-14IBR 14 Laptop - Intel Celeron - 2GB Memory - 32GB eMMC Flash Memory - Navy blue"', 13, 4, 2018, Decimal('174.99')),
#  (235, 'TL-SG108 8-Port 10/100/1000 Mbps Unmanaged Desktop Switch', 26, 4, 2018, Decimal('24.99')),
#  (236, 'Sony MDR-1000X/C Wireless Bluetooth Noise Cancelling Hi-Fi Headphones (Certified Refurbished)', 3, 14, 2018, Decimal('328.00')),
#  (237, 'Apple MNF72LL/A 61W USB-C Power Adapter', 2, 4, 2018, Decimal('69.00')),
#  (238, 'Logitech G433 7.1 Wired Gaming Headset with DTS Headphone: X 7.1 Surround for PC', 4, 4, 2018, Decimal('78.99')),
#  (239, 'Pioneer 200W 4x6 Inch 3 Way 4 Ohms Coaxial Car Audio Speakers Pair | TS-A4676R', 17, 5, 2018, Decimal('48.99')),
#  (240, 'WD 8TB My Cloud EX2 Ultra Network Attached Storage - NAS - WDBVBZ0080JCH-NESN', 37, 4, 2018, Decimal('394.99')),
#  (241, 'JBL Trip Visor Mount Portable Bluetooth Hands-Free Kit (Black)', 7, 5, 2018, Decimal('99.99')),
#  (242, 'SanDisk 8GB Clip Jam MP3 Player (Pink)', 9, 6, 2018, Decimal('34.99')),
#  (243, 'CORSAIR - ValueSelect 16GB (2PK x 8GB) 1.3 GHz DDR3 SDRAM Laptop Memory - Multi', 6, 4, 2018, Decimal('112.99')),
#  (244, 'R6i In-Ear Headphones (Black)', 27, 11, 2018, Decimal('64.95')),
#  (245, 'PA248Q 24 LED Backlit IPS Widescreen Monitor', 10, 4, 2018, Decimal('322.99')),
#  (246, 'Definitive Technology - DT Series 6.5 2-Way In-Ceiling Speaker (Each) - Black"', 33, 5, 2018, Decimal('181.99')),
#  (247, "AudioQuest - RJE Cinnamon 4.9' Ethernet Cable - Black/Red", 34, 4, 2018, Decimal('89.95')),
#  (248, 'SunBriteTV - Signature Series - 43 Class - LED - Outdoor - Partial Sun - 2160p - 4K UHD TV with HDR"', 22, 1, 2018, Decimal('2799.99')),
#  (249, 'AX860i Digital ATX 860W Power Supply', 6, 4, 2018, Decimal('209.99')),
#  (250, 'LG - 55 Class - LED - UJ7700 Series - 2160p - Smart - 4K UHD TV with HDR"', 15, 1, 2018, Decimal('751.99')),
#  (251, 'Level Active Wireless In-Ear Headphones (Black)', 1, 14, 2018, Decimal('99.99')),
#  (252, 'JBL Everest 750 Over-Ear Wireless Bluetooth Headphones (Gun Metal)', 7, 14, 2018, Decimal('299.99')),
#  (253, 'GP60NB50 8x Super-Multi Portable DVD Rewriter with M-DISC', 15, 4, 2018, Decimal('25.99')),
#  (254, 'SunBriteTV - Veranda Series - 43 Class - LED - Outdoor - Full Shade - 2160p - 4K UHD TV with HDR"', 22, 1, 2018, Decimal('1499.98')),
#  (255, 'Acer 15.6 Chromebook CB5-571-C4G4', 38, 4, 2018, Decimal('199.99')),
#  (256, 'WD Blue 1TB SATA 6 Gb/s 7200 RPM 64MB Cache 3.5 Inch Desktop Hard Drive (WD10EZEX)', 37, 4, 2018, Decimal('50.50')),
#  (257, 'Details About Netgear Powerline 1000 Mbps Wifi 802.11ac 1 Gigabit Port Plw1000100nas', 8, 4, 2018, Decimal('65.00')),
#  (258, 'MX Anywhere 2S Wireless Mouse', 4, 4, 2018, Decimal('49.93')),
#  (259, 'Samsung - 55 Class - LED - Curved - Q7C Series - 2160p - Smart - 4K UHD TV with HDR"', 1, 1, 2018, Decimal('2197.99')),
#  (260, 'Sony - 5.1-Ch. 3D / Smart Blu-ray Home Theater System - Black', 3, 7, 2019, Decimal('161.99')),
#  (261, 'Sony SRSXB3/BLK Portable Wireless Speaker with Bluetooth (Black)', 3, 5, 2019, Decimal('53.05')),
#  (262, 'CORSAIR CL-9011109-WW Lighting Node PRO', 6, 4, 2019, Decimal('66.17')),
#  (263, 'Yamaha - Mini Hi-Fi System - 40 W RMS - iPod Supported - Piano Black', 5, 10, 2019, Decimal('349.95')),
#  (264, 'Seagate - SkyHawk Surveillance HDD 6TB Internal SATA Hard Drive for Desktops', 14, 4, 2019, Decimal('199.99')),
#  (265, 'Elite A-20 2-Channel Integrated Amplifier', 17, 7, 2019, Decimal('299.99')),
#  (266, 'Yamaha - 6-1/2 2-Way In-Ceiling Speakers (Pair) - White"', 5, 5, 2019, Decimal('116.99')),
#  (267, 'Alpine - 5 x 7" 2-Way Coaxial Car Speakers with Poly-Mica Cones (Pair) - Black"', 35, 5, 2019, Decimal('66.99')),
#  (268, '450 Mbps 2.4/5GHz Wireless N Dual Band PCI Express Adapter', 26, 4, 2019, Decimal('39.99')),
#  (269, 'Definitive Technology - W9 Dual 5-1/4 180W 2-Way Wireless Speaker (Each) for Streaming Music - Black"', 33, 5, 2019, Decimal('699.98')),
#  (270, 'PNY - 16 GB (2PK x 8GB) 1.8 GHz DDR3 DIMM Desktop Memory Kit - Black', 18, 4, 2019, Decimal('89.95')),
#  (271, 'SanDisk - Ultra II 960GB Internal SATA Solid State Drive for Laptops', 9, 4, 2019, Decimal('253.99')),
#  (272, 'Sony - XB20 Portable Bluetooth Speaker - Blue', 3, 5, 2019, Decimal('99.99')),
#  (273, 'Yamaha - Natural Sound 6-1/2 3-Way In-Wall Speakers (Pair) - White"', 5, 5, 2019, Decimal('179.98')),
#  (274, 'Details About *new~sennheiser Hd 4.50 Btnc Wireless Noise Cancelling Headphones~touch Controls', 30, 14, 2019, Decimal('147.96')),
#  (275, 'JBL Everest Elite 100 NXTGen Noise-Cancelling Bluetooth In-Ear Headphones Black', 7, 5, 2019, Decimal('199.95')),
#  (276, 'Klipsch - Reference Series 2.1-Channel Soundbar System with 6-1/2 Wireless Subwoofer and Digital Amplifier - Black"', 27, 5, 2019, Decimal('349.99')),
#  (277, 'Polk Audio - Vanishing Series RT 7 3-Way In-Ceiling Speaker (Each) - White"', 21, 5, 2019, Decimal('249.99')),
#  (278, "AudioQuest - RJE Vodka 4.9' Ethernet Cable - Black/Blue", 34, 7, 2019, Decimal('339.99')),
#  (279, 'SVS - 12 800W Powered Subwoofer - Black"', 36, 5, 2019, Decimal('1199.98')),
#  (280, 'X900F-Series 75-Class HDR UHD Smart LED TV', 3, 1, 2019, Decimal('3799.99')),
#  (281, 'Details About Seagate 4 Terabyte (4tb) Superspeed Usb 3.0 Game Drive For Xbox One Stea4000402', 14, 4, 2019, Decimal('149.99')),
#  (282, 'Yamaha - Natural Sound 6-1/2 2-Way All-Weather Outdoor Speakers (Pair) - White"', 5, 5, 2019, Decimal('149.99')),
#  (283, 'Apple USB-C VGA Multiport Adapter', 2, 4, 2019, Decimal('69.00')),
#  (284, 'Pioneer - 8x External USB 3.0 Quad-Layer Blu-ray Disc DL DVD±RW/CD-RW Drive - Silver', 17, 4, 2019, Decimal('64.95')),
#  (285, 'h.ear go Wireless Speaker (Cinnabar Red)', 3, 5, 2019, Decimal('189.99')),
#  (286, 'Details About Bose Quietcomfort 35 Noise Cancelling Wireless Headphones Series Ii Qc35 Black', 24, 14, 2019, Decimal('349.99')),
#  (287, 'Details About Openbox Excellent: Asus Rog Gl502vm 15.6 Laptop Intel Core I7 12gb Me..."', 10, 4, 2019, Decimal('1045.99')),
#  (288, 'Asus - 2-in-1 15.6 4K Ultra HD Touch-Screen Laptop Intel Core i7 16GB Memory NVIDIA GeForce GTX 950M - 2TB HDD + 512GB SSD - Sandblasted matte black aluminum"', 10, 4, 2019, Decimal('983.99')),
#  (289, 'MM8077 7-Channel Power Amplifier', 28, 16, 2019, Decimal('2399.98')),
#  (290, 'Russound - 150W Indoor/Outdoor Speaker (Each) - Black', 29, 5, 2019, Decimal('249.99')),
#  (291, 'Sony XBR55X700D 55-Inch 4K Ultra HD Smart LED TV (2016 Model)', 3, 1, 2019, Decimal('798.00')),
#  (292, 'Sony SRS-XB41 Portable Wireless Bluetooth Speaker - Black - SRSXB41/B (Certified Refurbished)', 3, 5, 2019, Decimal('249.99')),
#  (293, 'Sony 43 Class 4K UHD (2160P) Smart LED TV (XBR43X800E)"', 3, 1, 2019, Decimal('999.99')),
#  (294, 'Sharp CD-BH950 240W 5-Disc Mini Shelf Speaker System with Cassette and Bluetooth', 32, 5, 2019, Decimal('199.99')),
#  (295, 'Logitech G933 Artemis Spectrum – Wireless RGB 7.1 Dolby and DST Headphone Surround Sound Gaming Headset – PC', 4, 4, 2019, Decimal('169.95')),
#  (296, 'R8000P Nighthawk X6S AC4000 Wireless Tri-Band Gigabit Router', 8, 4, 2019, Decimal('248.99')),
#  (297, 'PNY - 8GB 1.6 GHz DDR3 DIMM Desktop Memory - Green', 18, 4, 2019, Decimal('79.99')),
#  (298, 'Russound - 2-Way Outdoor Rock Loudspeaker (Each) - Gray Granite', 29, 5, 2019, Decimal('122.43')),
#  (299, 'Acer Predator G1-710 Desktop Computer - Intel Core i7-6700 3.4 GHz - 16 GB DDR4 SDRAM - 2 TB HDD + 512 GB SSD', 38, 4, 2019, Decimal('1744.99')),
#  (300, 'House of Marley', 20, 14, 2019, Decimal('69.00')),
#  (301, 'Samsung - 65 Class - LED - Curved - MU7500 Series - 2160p - Smart - 4K UHD TV with HDR"', 1, 1, 2019, Decimal('1099.00')),
#  (302, 'Apple - iPad Air 2 Wi-Fi + Cellular 128GB - Gold', 2, 4, 2019, Decimal('34.58')),
#  (303, 'Sony - 55 Class - LED - X800E Series - 2160p - Smart - 4K UHD TV with HDR"', 3, 1, 2019, Decimal('999.99')),
#  (304, 'YSP-4300 Digital Sound Projector Wireless Active Subwoofer (Black)', 5, 5, 2019, Decimal('1799.99')),
#  (305, 'Samsung - 850 EVO 500GB Internal SATA Solid State Drive for Laptops and PC', 1, 4, 2019, Decimal('199.99')),
#  (306, 'Universal Foldable Bluetooth Keyboard for Mobile Devices', 16, 4, 2019, Decimal('99.99')),
#  (307, 'Details About Alpine 400w 5.25 Typee Coaxial 2way Car Speakers | Spe5000"', 35, 5, 2019, Decimal('45.99')),
#  (308, 'Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 512GB Flash Storage (Latest Model) - Silver"', 2, 4, 2019, Decimal('1699.99')),
#  (309, 'BenQ - CineHome HT2050A 1080p DLP Projector - White', 40, 7, 2019, Decimal('749.00')),
#  (310, 'Lenovo - 2-in-1 11.6 Touch-Screen Chromebook - MT8173c - 4GB Memory - 32GB eMMC Flash Memory - Dark gray"', 13, 4, 2019, Decimal('279.00')),
#  (311, 'Logitech iPad Slim Folio: Case with Wireless Keyboard with Bluetooth (Black) - iPad 5th generation', 4, 4, 2019, Decimal('99.99')),
#  (312, 'Details About Netgear Cm700 Docsis 3.0 32x8 High Speed Cable Modem', 8, 4, 2019, Decimal('114.99')),
#  (313, 'MG278Q 27 Widescreen LED Backlit TN Gaming Monitor', 10, 4, 2019, Decimal('389.99')),
#  (314, 'LG - 65 Class - OLED - B7A Series - 2160p - Smart - 4K UHD TV with HDR"', 15, 1, 2019, Decimal('3013.98')),
#  (315, 'JBL - Reflect Contour 2 Wireless In-Ear Headphones - Black', 7, 14, 2019, Decimal('99.99')),
#  (316, 'Samsung - 65 Class - LED - Q7F Series - 2160p - Smart - 4K UHD TV with HDR"', 1, 1, 2019, Decimal('2397.99')),
#  (317, 'CORSAIR - VENGEANCE LPX Series 32GB (2PK 16GB) 2.133GHz DDR4 Desktop Memory - Black', 6, 4, 2019, Decimal('359.99')),
#  (318, 'Sennheiser - Digital Headphone Amplifier - Silver', 30, 13, 2019, Decimal('2199.99')),
#  (319, 'Apple - iPad mini 4 Wi-Fi + Cellular 128GB - Sprint - Silver', 2, 4, 2019, Decimal('22.08')),
#  (320, 'Samsung Galaxy Tab S3 Keyboard Cover', 1, 4, 2019, Decimal('84.99')),
#  (321, 'VS278Q-P 27 16:9 LCD Monitor', 10, 4, 2019, Decimal('184.00')),
#  (322, "AudioQuest - Chocolate 16.5' 4K Ultra HD In-Wall HDMI Cable - Brown", 34, 7, 2019, Decimal('289.98')),
#  (323, 'Details About New Logitech G230 981000541 Headset', 4, 4, 2019, Decimal('59.99')),
#  (324, '21.5 iMac with Retina 4K Display (Mid 2017)', 2, 4, 2019, Decimal('1691.99')),
#  (325, 'Details About Apple Macbook Pro 15.4 Laptop 500gb Silver"', 2, 4, 2019, Decimal('349.99')),
#  (326, 'Details About Samsung Electronics Un49mu8000 49inch 4k (2160p) Uhd Led Lcd Internet Smart Tv', 1, 1, 2019, Decimal('599.99')),
#  (327, 'HXi Series HX1200i 1200W 80 Plus Platinum Certified PSU ATX Power Supply Unit (Black)', 6, 4, 2019, Decimal('249.99')),
#  (328, 'WD - Red 3TB Internal SATA NAS Storage (OEM/Bare Drive)', 12, 4, 2019, Decimal('109.99')),
#  (329, 'TL-SF1008P 8-Port 10/100Mbps Desktop Switch with 4-Port PoE', 26, 4, 2019, Decimal('41.35')),
#  (330, 'Kenwood - 6.5 2-Way Marine Speakers with Polypropylene Cones (Pair) - Black"', 31, 5, 2019, Decimal('52.52')),
#  (331, 'Sony WH1000XM2/N Wireless Noise Cancelling Headphones (Gold)', 3, 14, 2019, Decimal('349.99')),
#  (332, 'CORSAIR K70 RGB RAPIDFIRE Mechanical Gaming Keyboard - USB Passthrough and Media Controls - Fastest and Linear - Cherry MX Speed - RGB LED Backlit', 6, 4, 2019, Decimal('129.99')),
#  (333, 'AW-650 All-Weather Outdoor Speaker (Pair, White)', 27, 5, 2019, Decimal('449.00')),
#  (334, 'SanDisk - 120GB Internal SATA Solid State Drive Plus for Laptops', 9, 4, 2019, Decimal('69.00')),
#  (335, '32GB iPod touch (Pink) (6th Generation)', 2, 6, 2019, Decimal('229.99')),
#  (336, '12 MacBook (Mid 2017, Silver)', 2, 4, 2019, Decimal('1299.99')),
#  (337, 'Lenovo 80TX0007US Y 710-11ISK 11.6-Inch FHD Touch Laptop (Pentium 4405Y, 4 GB Ram, 128 GB SSD, Windows 10), SilverNotebook PC Computer Tablet Touchscreen Screen 2-in-1', 13, 4, 2019, Decimal('349.99')),
#  (338, 'Details About Openbox Excellent: Lg 32 Class (31.5" Diag.) Led 720p Smart Hdtv"', 15, 1, 2019, Decimal('199.99')),
#  (339, 'Reference Premiere RP-240S Surround Speaker (Single, Black)', 27, 5, 2019, Decimal('289.98')),
#  (340, 'Details About Microsoft Surface Ergonomic Bluetooth Wireless Keyboard Silver 3ra00022', 16, 4, 2019, Decimal('72.00')),
#  (341, 'Asus - 17.3 Laptop - Intel Pentium - 8GB Memory - 1TB Hard Drive - Black"', 10, 4, 2019, Decimal('540.57')),
#  (342, 'Pioneer - 5.1-Ch. Network-Ready 4K Ultra HD and 3D Pass-Through HDR Compatible A/V Home Theater Receiver - Black', 17, 7, 2019, Decimal('349.99')),
#  (343, 'Chant Sport BT Portable Audio System (Black)', 20, 5, 2019, Decimal('75.11')),
#  (344, 'Details About Microsoft Surface Pen Burgundy (2017) #eyu00025 New Sealed In Box', 16, 4, 2019, Decimal('99.99')),
#  (345, 'Razer Electra V2-7.1 Surround Sound Digital Gaming Headset with Detachable Microphone', 11, 4, 2019, Decimal('71.26')),
#  (346, 'Definitive Technology - DT Series 8 2-Way In-Ceiling Speaker (Each) - Black"', 33, 5, 2019, Decimal('249.00')),
#  (347, 'Toshiba - 1TB Internal SATA Hard Drive for Desktops', 25, 4, 2019, Decimal('54.39')),
#  (348, 'Veranda Series 65-Class UHD Outdoor LED TV', 22, 1, 2019, Decimal('3499.99')),
#  (349, 'Netgear N900 Wireless Dual Band USB Adapter', 8, 4, 2019, Decimal('12.49')),
#  (350, 'New Asus Q524u 15.6fhd 2in1 Touch I77500u 3.5ghz 16gb Ddr4 2tb Hd 940mx2gb W10"', 10, 4, 2019, Decimal('764.99')),
#  (351, 'Samsung Leather Flip Book Cover Case for Samsung Galaxy Note 10.1 2014 Edition - Black Retail Packaging"', 1, 4, 2019, Decimal('19.99')),
#  (352, 'JBL - 5-1/4 2-Way Car Speakers with Polypropylene Cones (Pair) - Black"', 7, 5, 2019, Decimal('89.99')),
#  (353, 'WD - My Book Pro 6TB 2-Bay External Thunderbolt, USB 3.0 Storage - Black', 12, 4, 2019, Decimal('549.99')),
#  (354, 'CORSAIR - VENGEANCE RGB Series 16GB (2PK 8GB) 3.0GHz DDR4 Desktop Memory with RGB Lighting - Black', 6, 4, 2019, Decimal('132.50')),
#  (355, 'Samsung T5 Portable SSD - 500GB - USB 3.1 External SSD (MU-PA500B/AM)', 1, 4, 2019, Decimal('149.99')),
#  (356, '64GB XQD G Series Memory Card', 3, 4, 2019, Decimal('108.49')),
#  (357, 'Dell - Inspiron 15.6 Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce GTX 1050 - 1TB + 8GB Hybrid Hard Drive - Red"', 19, 4, 2019, Decimal('799.99')),
#  (358, 'Sony MDRXB950B1 Extra Bass Wireless Headphones App Control BLACK #97 (GRADE A)', 3, 14, 2019, Decimal('59.95')),
#  (359, 'Apple MacBook - 12 - Core m5 - 8 GB RAM - 512 GB flash storage - English"', 2, 4, 2019, Decimal('1.00')),
#  (360, 'Apple iPod Touch', 2, 6, 2019, Decimal('279.99')),
#  (361, 'Yamaha - Natural Sound 5 2-Way All-Weather Outdoor Speakers (Pair) - Black"', 5, 5, 2019, Decimal('77.99')),
#  (362, 'Seagate Backup Plus 2TB Portable External Hard Drive for Mac USB 3.0 + 2mo Adobe CC Photography (STDS2000100)', 14, 4, 2019, Decimal('74.00')),
#  (363, 'Details About Razer Mamba Chroma Professional Grade Esports Wired/wireless Ergonomic Gaming', 11, 4, 2019, Decimal('134.99')),
#  (364, 'Details About Logitech 920008149 K780 Wrls Multi Device Keyb', 4, 4, 2019, Decimal('170.71')),
#  (365, 'HP - Stream 14 Laptop - Intel Celeron - 4GB - 32GB eMMC Flash Memory - Office 365 Personal 1-Year Subscription Included - Aqua blue"', 39, 4, 2019, Decimal('114.50')),
#  (366, "Forest High-Speed HDMI Cable with Ethernet (26.3')", 34, 13, 2019, Decimal('219.95')),
#  (367, 'SRS-XB2 Portable Bluetooth Wireless Speaker (Blue)', 3, 5, 2019, Decimal('79.99')),
#  (368, 'Apple MacBook Pro MLUQ2LL/A 13.3 Notebook - Intel Core i5 Dual-core (2 Core) 2 GHz - 8 GB LPDDR3 - 256 GB SSD - Mac OS X 10.12 Sierra - 2560 x 1600 - In-plane Switching (IPS) Technology - Silver"', 2, 4, 2019, Decimal('1.00')),
#  (369, 'h.ear go Wireless Speaker (Lime Yellow)', 3, 5, 2019, Decimal('199.99')),
#  (370, 'Logitech Keys-To-Go Ultra-Portable Bluetooth Keyboard for Android and Windows', 4, 4, 2019, Decimal('28.88')),
#  (371, 'LG Electronics OLED65C6P Curved 65-Inch 4K Ultra HD Smart OLED TV (2016 Model)', 15, 1, 2019, Decimal('3.00')),
#  (372, 'Details About Microsoft Surface Arc Touch Mouse Wireless Bluetooth Platinum', 16, 4, 2019, Decimal('79.99')),
#  (373, 'Logitech - Harmony Home Companion - Black', 4, 13, 2019, Decimal('78.45')),
#  (374, '15.4 MacBook Pro with Touch Bar (Late 2016, Silver)', 2, 4, 2019, Decimal('2.00')),
#  (375, '3TB AirPort Time Capsule (5th Generation)', 2, 4, 2019, Decimal('370.75')),
#  (376, 'Apple MacBook Pro with Touch Bar - 13.3 - Core i5 - 8 GB RAM - 512 GB SSD - English"', 2, 4, 2019, Decimal('1.00')),
#  (377, 'Logitech H800 Wireless Headset for PC, Tablets and Smartphones', 4, 4, 2019, Decimal('56.99')),
#  (378, 'Samsung 860 EVO 250GB 2.5 SATA III SSD Retail MZ-76E250B/AM - 5 Year WRT - NoTax', 1, 4, 2019, Decimal('84.99')),
#  (379, 'Details About Lg 49uj6200 49inch 4k Uhd 4k 2160p Hdr Led Tm120 Smart Hdtv (no Stand)', 15, 1, 2019, Decimal('306.76')),
#  (380, 'Seagate Backup Plus Hub 8TB External Desktop Hard Drive Storage + 2mo Adobe CC Photography (STEL8000100)', 14, 4, 2019, Decimal('199.99')),
#  (381, 'Toshiba X300 4TB Performance Desktop and Gaming Hard Drive 7200 RPM 128MB Cache SATA 6.0Gb/s 3.5 Inch Internal Hard Drive (HDWE140XZSTA)', 25, 4, 2019, Decimal('129.88')),
#  (382, 'Magic Keyboard with Numeric Keypad - US English - Space Gray', 2, 4, 2019, Decimal('149.99')),
#  (383, 'ASUS CHROMEBOX2-G095U Mini Chrome OS Computer', 10, 4, 2019, Decimal('169.99')),
#  (384, 'Asus - 27 IPS LED HD GSync Monitor - Black"', 10, 4, 2019, Decimal('799.99')),
#  (385, '8GB Clip Jam MP3 Player (Green)', 9, 6, 2019, Decimal('29.99')),
#  (386, 'PNY - Performance 16GB (2PK 8GB) 1.6GHz DDR3 Desktop Memory - Green', 18, 4, 2019, Decimal('179.99')),
#  (387, 'Details About Corsair K55 Rgb Backlit Gaming Keyboard', 6, 4, 2019, Decimal('48.99')),
#  (388, 'ProSafe 16-Port 10/100 Desktop Switch', 8, 4, 2019, Decimal('52.99')),
#  (389, 'Apple - iPod touch® 32GB MP3 Player - Space Gray', 2, 6, 2019, Decimal('179.95')),
#  (390, 'h.ear go Wireless Speaker (Bordeaux Pink)', 3, 5, 2019, Decimal('189.99')),
#  (391, '32GB iPod touch (Gold) (6th Generation)', 2, 6, 2019, Decimal('190.99')),
#  (392, 'Logitech - Logi FOCUS Keyboard Folio Case for Apple® iPad® mini 4 - Black', 4, 4, 2019, Decimal('131.70')),
#  (393, 'Logitech - Logi FOCUS Keyboard Folio Case for Apple® iPad® mini 4 - Black', 4, 4, 2019, Decimal('82.47')),
#  (394, 'PNY - NVIDIA GeForce GTX 1060 6GB GDDR5 PCI Express 3.0 Graphics Card - Black', 18, 4, 2019, Decimal('259.54')),
#  (395, 'Yamaha - WX-010 Wireless Speaker for Streaming Music - Black', 5, 5, 2019, Decimal('179.95')),
#  (396, 'Mac mini 2.6 GHz Desktop Computer (Late 2014)', 2, 4, 2019, Decimal('629.00')),
#  (397, 'Definitive Technology - SuperCube 2000 7-1/2 650W Powered Subwoofer - Black"', 33, 5, 2019, Decimal('467.99')),
#  (398, 'Power Supply for Surface Book Surface Pro', 16, 4, 2019, Decimal('60.13')),
#  (399, '240GB SSD Plus SATA III 2.5 Internal SSD', 9, 4, 2019, Decimal('67.99')),
#  (400, '240GB SSD Plus SATA III 2.5 Internal SSD', 9, 4, 2020, Decimal('97.13')),
#  (401, 'Sony MDRXB950N1 Headphones Bluetooth Noise Cancel Extra Bass Blk MDR-XB950N1 #95', 3, 14, 2020, Decimal('105.94')),
#  (402, 'Details About Seagate 1tb Internal Serial Ata Hard Drive For Laptops', 14, 4, 2020, Decimal('69.91')),
#  (403, '21.5 iMac (Mid 2017)', 2, 4, 2020, Decimal('999.00')),
#  (404, 'XB80BS Extra Bass Sports In-Ear Bluetooth Headphones (Black)', 3, 14, 2020, Decimal('149.99')),
#  (405, 'Samsung Galaxy Tab E Lite 7 8gb White - Sm-T113nykaxar', 1, 4, 2020, Decimal('119.99')),
#  (406, 'SRS-XB10 Bluetooth Speaker (White)', 3, 5, 2020, Decimal('58.00')),
#  (407, 'Apple 13.3 MacBook Air ( Silver)"', 2, 4, 2020, Decimal('843.49')),
#  (408, 'Logitech - Harmony Ultimate Home Remote - Black', 4, 13, 2020, Decimal('191.99')),
#  (409, 'CORSAIR - Hydro Series 240mm Liquid CPU Cooler - Black/Gray', 6, 4, 2020, Decimal('144.98')),
#  (410, 'CORSAIR - Hydro Series 240mm Liquid CPU Cooler - Black/Gray', 6, 4, 2020, Decimal('93.01')),
#  (411, 'CORSAIR - Hydro Series 240mm Liquid CPU Cooler - Black/Gray', 6, 4, 2020, Decimal('104.99')),
#  (412, '9.7 iPad (2017, 32GB, Wi-Fi Only, Silver)', 2, 4, 2020, Decimal('319.99')),
#  (413, 'Polk Audio - PSW Series 10 Active Subwoofer - Black"', 21, 5, 2020, Decimal('239.99')),
#  (414, 'Polk Audio - PSW Series 10 Active Subwoofer - Black"', 21, 5, 2020, Decimal('164.99')),
#  (415, 'Details About Microsoft Surface Pen Stylus W/ Tip Kit For Surface Pro 3', 16, 4, 2020, Decimal('51.99')),
#  (416, 'Seagate - Wireless Plus 2TB Portable Hard Drive - Gray', 14, 4, 2020, Decimal('179.99')),
#  (417, 'Asus Zenbook Ux303uadh51t 13.3 Fhd Touchscreen Core I56200u 8gb 256gb"', 10, 4, 2020, Decimal('849.75')),
#  (418, 'WD - Red Pro 4TB Internal SATA NAS Hard Drive', 12, 4, 2020, Decimal('199.99')),
#  (419, 'WD - Blue 500GB Internal Serial ATA Hard Drive for Laptops (OEM/Bare Drive)', 12, 4, 2020, Decimal('50.00')),
#  (420, 'CORSAIR - VENGEANCE LED Series 16GB (2PK 8GB) 3.0GHz DDR4 Desktop Memory with LED Lighting - Black', 6, 4, 2020, Decimal('146.99')),
#  (421, 'Surface Dock', 16, 4, 2020, Decimal('199.99')),
#  (422, 'Details About Logitech G903 Lightspeed Wireless Gaming Mouse', 4, 4, 2020, Decimal('149.99')),
#  (423, 'SunBriteTV SB-WM46 46-Inch Dual Arm Articulating Wall Mount', 22, 13, 2020, Decimal('446.99')),
#  (424, 'Marantz - 11.2-Ch. Network-Ready 4K Ultra HD and 3D Pass-Through A/V Home Theater Preamplifier - Black', 28, 7, 2020, Decimal('2499.00')),
#  (425, 'V206HQL Abd 19.5 LED Backlit LCD Monitor (Black)', 38, 4, 2020, Decimal('77.29')),
#  (426, 'Asus RT-AC5300 IEEE 802.11ac Ethernet Wireless Router - 2.40 GHz ISM Band - 5 GHz UNII Band - 8 x Antenna(8 x External) - 5334 Mbit/s Wireless Speed - 4 x Network Port - 1 x Broadband Port - USB - Gig', 10, 4, 2020, Decimal('355.72')),
#  (427, 'SanDisk Extreme 500 480GB USB 3.0 Portable SSD (Solid State Drive) - SDSSDEXT-480G', 9, 4, 2020, Decimal('187.47')),
#  (428, 'Magic Keyboard Mouse BH Kit', 2, 4, 2020, Decimal('105.98')),
#  (429, 'Magic Keyboard Mouse BH Kit', 2, 4, 2020, Decimal('173.98')),
#  (430, 'HP 15-ba009dx 15.6 AMD A6-7310 2GHz 4GB DDR3 500GB HDD Radeon R4 W10 Refurbished"', 39, 4, 2020, Decimal('359.99')),
#  (431, 'Razer Kraken Pro Gaming Headset Green', 11, 4, 2020, Decimal('90.55')),
#  (432, 'Details About Apple Macbook Air 13.3 Laptop (early 2015) 2.2ghz Core I7 8gb 256gb"', 2, 4, 2020, Decimal('1099.99')),
#  (433, 'SoundSport Wireless In-Ear Headphones (Black)', 24, 14, 2020, Decimal('149.00')),
#  (434, 'Kenwood - In-Dash Digital Media Receiver - Bluetooth - Satellite Radio-ready with Detachable Faceplate - Black', 31, 15, 2020, Decimal('75.99')),
#  (435, 'Yamaha RX-V681BL 7.2-Channel MusicCast AV Receiver with Bluetooth', 5, 7, 2020, Decimal('599.95')),
#  (436, 'SAMSUNG 40 Class FHD (1080P) Smart LED TV (UN40J5200AF)"', 1, 4, 2020, Decimal('429.99')),
#  (437, 'JBL Clip2 Portable Speaker', 7, 5, 2020, Decimal('39.99')),
#  (438, 'Apple - iPad Pro 12.9-inch (Latest Model) with Wi-Fi + Cellular - 512 GB - Gold', 2, 4, 2020, Decimal('1279.99')),
#  (439, 'Details About Genuine Used Apple 85w Magsafe Power Adapter Mc556ll/b Model A1343 1185cl', 2, 4, 2020, Decimal('81.89')),
#  (440, 'Samsung - 88 Class - LED - Q9F Series - 2160p - Smart - 4K UHD TV with HDR"', 1, 1, 2020, Decimal('16999.95')),
#  (441, 'Chant Sport BT Portable Audio System (Natural)', 20, 5, 2020, Decimal('78.00')),
#  (442, 'Sony - 49 Class - LED - X900E Series - 2160p - Smart - 4K UHD TV with HDR"', 3, 1, 2020, Decimal('898.00')),
#  (443, 'JBL - Everest 110 Wireless In-Ear Headphones - Gunmetal', 7, 14, 2020, Decimal('79.99')),
#  (444, 'Details About Asus Q304 13.3 Laptop I5 2.5 Ghz 6gb 1tb Hdd Win 10 (q304uabhi5t11)"', 10, 4, 2020, Decimal('644.52')),
#  (445, 'Details About Razer Blackwidow Chroma V2', 11, 4, 2020, Decimal('103.89')),
#  (446, 'PNY - 16 GB (2PK x 8GB) 1.6 GHz DDR3L SoDIMM Laptop Memory Kit - Green', 18, 4, 2020, Decimal('99.99')),
#  (447, '12.3 32GB Multi-Touch 2-in-1 Chromebook Plus', 1, 4, 2020, Decimal('414.00')),
#  (448, 'Details About Dell Inspiron I75675650blkpus 15.6 Laptop I57300hq"', 19, 4, 2020, Decimal('809.99')),
#  (449, 'Apple 45W MagSafe 2 Power Adapter for Macbook Air (MD592LL/A)', 2, 4, 2020, Decimal('76.99')),
#  (450, 'Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Space Gray"', 2, 4, 2020, Decimal('1499.99')),
#  (451, '4TB My Book Desktop USB 3.0 External Hard Drive', 12, 4, 2020, Decimal('119.99')),
#  (452, 'Razer Ripsaw USB 3.0 Game Stream and Capture Card for PC', 11, 4, 2020, Decimal('125.00')),
#  (453, 'Dell XPS 15 15.6 4K Touchcreen Laptop Intel i7-6700HQ 16GB 1TB SSD GTX 960M"', 19, 4, 2020, Decimal('2379.00')),
#  (454, 'Kenwood - CD - Built-In Bluetooth - Apple® iPod®- and Satellite Radio-Ready - In-Dash Deck - Black', 31, 15, 2020, Decimal('119.66')),
#  (455, 'SanDisk - Ultra 32GB microSDHC Class 10 Memory Card', 9, 4, 2020, Decimal('16.91')),
#  (456, 'Apple - 21.5 iMac® - Intel Core i5 - 8GB Memory - 1TB Hard Drive - Silver"', 2, 4, 2020, Decimal('999.99')),
#  (457, 'SP-T22A-LR Dolby Atmos-Enabled Add-On Speakers (Pair, Black)', 17, 5, 2020, Decimal('199.99')),
#  (458, 'Polk Audio - SurroundBar 8-Channel Soundbar System with 8 Wireless Subwoofer - Black"', 21, 7, 2020, Decimal('799.99')),
#  (459, 'Polk Audio - SurroundBar 8-Channel Soundbar System with 8 Wireless Subwoofer - Black"', 21, 7, 2020, Decimal('699.99')),
#  (460, 'Polk Audio - SurroundBar 8-Channel Soundbar System with 8 Wireless Subwoofer - Black"', 21, 7, 2020, Decimal('799.95')),
#  (461, 'CORSAIR - Carbide Series Clear® 400C Compact ATX/EATX/Mini-ITX/Micro ATX Mid-Tower Case - White', 6, 4, 2020, Decimal('94.99')),
#  (462, 'PM7005 2-Channel Integrated Amplifier', 28, 16, 2020, Decimal('1299.00')),
#  (463, 'PM7005 2-Channel Integrated Amplifier', 28, 16, 2020, Decimal('999.00')),
#  (464, 'X850F-Series 75-Class HDR UHD Smart LED TV', 3, 1, 2020, Decimal('3298.00')),
#  (465, 'Samsung - Galaxy Tab E - 9.6 - 16GB - Black"', 1, 4, 2020, Decimal('197.99')),
#  (466, 'Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Silver"', 2, 4, 2020, Decimal('1972.59')),
#  (467, 'Russound - 2-Way Outdoor Rock Loudspeaker (Each) - Weathered Granite', 29, 5, 2020, Decimal('121.28')),
#  (468, 'Apple - Smart Cover for Apple iPad and iPad® Air 2 - Charcoal Gray', 2, 4, 2020, Decimal('29.95')),
#  (469, 'Apple - MacBook Pro 13.3 Pre-owned Laptop - Intel Core i5 - 4GB Memory - 320GB - Silver"', 2, 4, 2020, Decimal('339.95')),
#  (470, 'Apple - MacBook Pro 13.3 Pre-owned Laptop - Intel Core i5 - 4GB Memory - 320GB - Silver"', 2, 4, 2020, Decimal('576.99')),
#  (471, 'Details About Razer Basilisk Ergonomic Fps Gaming Mousefast', 11, 4, 2020, Decimal('59.99')),
#  (472, 'Toshiba - 1TB Internal SATA Hard Drive for Laptops', 25, 4, 2020, Decimal('52.99')),
#  (473, 'WD - Blue 500GB Internal SATA Hard Drive', 12, 4, 2020, Decimal('49.99')),
#  (474, 'CORSAIR - DOMINATOR PLATINUM 32GB (2PK 16GB) 3.0GHz DDR4 Desktop Memory with DHX cooling - Black/silver', 6, 4, 2020, Decimal('687.00')),
#  (475, 'CORSAIR - DOMINATOR PLATINUM 32GB (2PK 16GB) 3.0GHz DDR4 Desktop Memory with DHX cooling - Black/silver', 6, 4, 2020, Decimal('216.22')),
#  (476, 'CORSAIR - DOMINATOR PLATINUM 32GB (2PK 16GB) 3.0GHz DDR4 Desktop Memory with DHX cooling - Black/silver', 6, 4, 2020, Decimal('293.99')),
#  (477, 'Yamaha - AVENTAGE 9.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black', 5, 16, 2020, Decimal('1599.98')),
#  (478, '7.0 Tab A 8GB Tablet (Wi-Fi Only, Black)', 1, 4, 2020, Decimal('83.20')),
#  (479, 'NETGEAR - AC600 Dual-Band WiFi USB Mini Adapter - Black', 8, 4, 2020, Decimal('10.99')),
#  (480, 'Samsung Galaxy Tab E Lite Kids 7; 8 GB Wifi Tablet (White) SM-T113NDWACCC"', 1, 4, 2020, Decimal('69.85')),
#  (481, 'Sony - Premium Jacket Camera Case - Black', 3, 9, 2020, Decimal('55.95')),
#  (482, 'Sony - Premium Jacket Camera Case - Black', 3, 9, 2020, Decimal('78.99')),
#  (483, '391 Series C32F391 32 16:9 Curved FreeSync LCD Monitor', 1, 4, 2020, Decimal('349.99')),
#  (484, 'Chant Mini Portable Bluetooth Wireless Speaker (Navy)', 20, 5, 2020, Decimal('39.99')),
#  (485, 'TL-SG1008P 8-Port Gigabit Desktop Switch with 4-Port PoE', 26, 4, 2020, Decimal('66.46')),
#  (486, 'PNY - XLR8 NVIDIA GeForce GTX 1080 8GB GDDR5X PCI Express 3.0 Graphics Card - Black/Red', 18, 4, 2020, Decimal('619.99')),
#  (487, 'Apple - Pre-owned 9.7-inch iPad Pro - 128GB - Space gray', 2, 4, 2020, Decimal('650.99')),
#  (488, 'Sony 65 Class 4K (2160P) Smart OLED TV (XBR65A1E)"', 3, 1, 2020, Decimal('4275.00')),
#  (489, 'Sony - XB7 Extra Bass Audio System with Bluetooth - Black', 3, 5, 2020, Decimal('248.00')),
#  (490, 'Details About Netgear Cm1000 Docsis 3.1 Ultrahigh Speed Cable Modem', 8, 4, 2020, Decimal('171.98')),
#  (491, 'Samsung - Notebook 5 15.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce 920MX - 1TB Hard Drive - Solid black"', 1, 4, 2020, Decimal('799.97')),
#  (492, '2TB My Passport USB 3.0 Secure Portable Hard Drive (Orange)', 12, 4, 2020, Decimal('69.00')),
#  (493, '27 iMac with Retina 5K Display (Mid 2017)', 2, 4, 2020, Decimal('2115.99')),
#  (494, 'LG Electronics OLED65E6P Flat 65-Inch 4K Ultra HD Smart OLED TV (2016 Model)', 15, 1, 2020, Decimal('4296.99')),
#  (495, 'SRS-ZR5 Wireless Speaker', 3, 5, 2020, Decimal('199.99')),
#  (496, 'Samsung UN65KS9500 65-inch Smart 4K UHD TV', 1, 1, 2020, Decimal('2495.00')),
#  (497, 'Logitech - M570 Wireless Trackball Mouse - Gray/Blue', 4, 4, 2020, Decimal('41.98')),
#  (498, 'Logitech - M570 Wireless Trackball Mouse - Gray/Blue', 4, 4, 2020, Decimal('39.99')),
#  (499, 'USB Type-C Digital AV Multiport Adapter', 2, 4, 2020, Decimal('33.95')),
#  (500, 'Samsung - 40 Class - LED - MU7000 Series - 2160p - Smart - 4K UHD TV with HDR"', 1, 1, 2020, Decimal('551.99')),
#  (501, 'Polk Audio - 7 3-Way Floor Speaker (Each) - Cherry"', 21, 5, 2020, Decimal('79.72')),
#  (502, 'BL2711U 27 16:9 4K UHD IPS Monitor', 40, 4, 2020, Decimal('589.99')),
#  (503, 'BL2711U 27 16:9 4K UHD IPS Monitor', 40, 4, 2020, Decimal('609.00')),
#  (504, 'Dell USB 3.0 Ultra HD/4K Triple Display Docking Station (D3100)', 19, 4, 2020, Decimal('169.99')),
#  (505, 'Definitive Technology - ProCinema 600 5.1-Channel Home Theater Speaker System - Black', 33, 5, 2020, Decimal('1149.95')),
#  (506, 'Definitive Technology - ProCinema 600 5.1-Channel Home Theater Speaker System - Black', 33, 5, 2020, Decimal('521.99')),
#  (507, '13.3 MacBook Air (Mid 2017, Silver)', 2, 4, 2020, Decimal('979.00')),
#  (508, 'CORSAIR M65 Pro RGB - FPS Gaming Mouse - 12', 6, 4, 2020, Decimal('114.88')),
#  (509, 'CORSAIR M65 Pro RGB - FPS Gaming Mouse - 12', 6, 4, 2020, Decimal('59.99')),
#  (510, 'Seagate - 2TB Internal SATA Hard Drive for Laptops', 14, 4, 2020, Decimal('109.99')),
#  (511, 'Details About Seagate Expansion 1tb External Usb 3.0 Portable Hard Drive Black', 14, 4, 2020, Decimal('69.99')),
#  (512, 'Liberate XLBT Bluetooth Headphones (Midnight)', 20, 14, 2020, Decimal('169.20')),
#  (513, 'Liberate XLBT Bluetooth Headphones (Midnight)', 20, 14, 2020, Decimal('128.99')),
#  (514, 'Apple - Pre-owned 9.7-inch iPad Pro - 32GB - Space gray', 2, 4, 2020, Decimal('479.00')),
#  (515, 'Logitech K800 Wireless Illuminated Keyboard — Backlit Keyboard', 4, 4, 2020, Decimal('62.99')),
#  (516, 'LG - Super-Multi 24x External USB 2.0 Double-Layer DVD±/CD-RW Drive - Black', 15, 4, 2020, Decimal('39.99')),
#  (517, 'Samsung Level U PRO Headphones with ANC, Black', 1, 14, 2020, Decimal('99.99')),
#  (518, 'JBL - 6 x 9" 3-Way Car Speakers with Polypropylene Cones (Pair) - Black"', 7, 5, 2020, Decimal('79.99')),
#  (519, 'JBL - 6 x 9" 3-Way Car Speakers with Polypropylene Cones (Pair) - Black"', 7, 5, 2020, Decimal('64.99')),
#  (520, 'HP - ProBook 14 Laptop - Intel Core i5 - 4GB Memory - 500GB Hard Drive - Black"', 39, 4, 2020, Decimal('899.09'))]

# %%
df_prod = pd.read_sql("SELECT * FROM product.product", con = conn)
df_prod.head(10)
# Out:
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_11004\4164110988.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_prod = pd.read_sql("SELECT * FROM product.product", con = conn)
#    product_id                                       product_name  brand_id  \
# 0           1  DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...        23
# 1           2  NS-SP1800BL 5.1-Channel Home Theater System (B...         5
# 2           3  Acoustimass 6 Series V Home Theater Speaker Sy...        24
# 3           4  Corsair Vengeance LPX 16GB (2x8GB) DDR4 DRAM 3...         6
# 4           5  Details About Samsung Gear Iconx 2018 Edition ...         1
# 5           6     2TB Red 5400 rpm SATA III 3.5 Internal NAS HDD        12
# 6           7  Details About Alpine 480w 6.5 2way Typee Coaxi...        35
# 7           8  Kenwood KFC-1653MRW 6.5 2-way Marine Speakers ...        31
# 8           9  Microsoft Surface Pro 4 Type Cover with Finger...        16
# 9          10  CORSAIR VENGEANCE RGB 16GB (2x8GB) DDR4 3200MH...         6
#
#    category_id  model_year  list_price
# 0            4        2021       23.99
# 1            5        2021      136.99
# 2            5        2021      599.00
# 3            4        2021      151.99
# 4           14        2021      199.99
# 5            4        2021       89.95
# 6            5        2021       59.99
# 7            5        2021       99.99
# 8            4        2021      121.99
# 9            4        2021      174.99

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to transfer a dataframe to SQL Server?</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Using PyODBC</p>
#
# <a id="6.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>Although the way to send a Dataframe to SQL Server using the <font color=red>PyODBC</font> module is a bit indirect, it can meet the need. To do this, you first need to create an empty table with the column structure of the Dataframe you will send to SQL Server, and then insert the data from the Dataframe into this table.</font>

# %%
query = """
        CREATE TABLE product_new1 (
            product_id int,
            product_name varchar(255),
            brand_id int,
            category_id int ,
            model_year int,
            list_price decimal(10,2)
        )
        """
execute_query(conn, query)
# Out:
# Query Succeessful!

# %%
df_prod.to_dict('records')
# Out:
# [{'product_id': 1,
#   'product_name': 'DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 1710 1715 1730 1735 1750 1755 1955 3000 3005 A100 M30X M35X - Black',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 23.99},
#  {'product_id': 2,
#   'product_name': 'NS-SP1800BL 5.1-Channel Home Theater System (Black)',
#   'brand_id': 5,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 136.99},
#  {'product_id': 3,
#   'product_name': 'Acoustimass 6 Series V Home Theater Speaker System (Black)',
#   'brand_id': 24,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 599.0},
#  {'product_id': 4,
#   'product_name': 'Corsair Vengeance LPX 16GB (2x8GB) DDR4 DRAM 3000MHz C15 Desktop Memory Kit - Black (CMK16GX4M2B3000C15)',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 151.99},
#  {'product_id': 5,
#   'product_name': 'Details About Samsung Gear Iconx 2018 Edition Cordfree Fitness Earbuds Black (us Version)',
#   'brand_id': 1,
#   'category_id': 14,
#   'model_year': 2021,
#   'list_price': 199.99},
#  {'product_id': 6,
#   'product_name': '2TB Red 5400 rpm SATA III 3.5 Internal NAS HDD',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 89.95},
#  {'product_id': 7,
#   'product_name': 'Details About Alpine 480w 6.5 2way Typee Coaxial Car Speakers W/ Silk Tweeters | Spe6000"',
#   'brand_id': 35,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 59.99},
#  {'product_id': 8,
#   'product_name': 'Kenwood KFC-1653MRW 6.5 2-way Marine Speakers Pair (White)"',
#   'brand_id': 31,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 99.99},
#  {'product_id': 9,
#   'product_name': 'Microsoft Surface Pro 4 Type Cover with Fingerprint ID',
#   'brand_id': 16,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 121.99},
#  {'product_id': 10,
#   'product_name': 'CORSAIR VENGEANCE RGB 16GB (2x8GB) DDR4 3200MHz C16 Desktop Memory - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 174.99},
#  {'product_id': 11,
#   'product_name': 'DENAQ - AC Power Adapter and Charger for Select HP Omnibook, Pavilion and Presario Laptops - Black',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 29.99},
#  {'product_id': 12,
#   'product_name': 'Samsung - 50 Class (49.5" Diag.) - LED - 1080p - Smart - HDTV"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2021,
#   'list_price': 499.99},
#  {'product_id': 13,
#   'product_name': 'Polk Audio - 50 W Woofer - Black',
#   'brand_id': 21,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 99.99},
#  {'product_id': 14,
#   'product_name': 'Apple - Pre-Owned iPad 3 - 64GB - Black',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 249.99},
#  {'product_id': 15,
#   'product_name': 'Corsair CMSA8GX3M2A1066C7 Apple 8 GB Dual Channel Kit DDR3 1066 (PC3 8500) 204-Pin DDR3 Laptop SO-DIMM Memory 1.5V',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 67.99},
#  {'product_id': 16,
#   'product_name': 'Virtually Invisible 891 In-Wall Speakers (Pair)',
#   'brand_id': 24,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 599.0},
#  {'product_id': 17,
#   'product_name': 'DENAQ - AC Power Adapter and Charger for Select Toshiba Satellite and Satellite Pro Laptops - Black',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 11.99},
#  {'product_id': 18,
#   'product_name': 'Lenovo - AC Adapter for Select Lenovo Yoga Laptops - Black',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 24.99},
#  {'product_id': 19,
#   'product_name': 'Sony - SRS-XB21 Portable Bluetooth Speaker - Black',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 99.99},
#  {'product_id': 20,
#   'product_name': 'Russound - Acclaim 5 Series 6-1/2 Indoor/Outdoor Speaker (Each) - White"',
#   'brand_id': 29,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 249.99},
#  {'product_id': 21,
#   'product_name': 'SB-2000 12 500W Subwoofer (Piano Gloss Black)',
#   'brand_id': 36,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 799.98},
#  {'product_id': 22,
#   'product_name': 'Kenwood - Road Series 6 x 8" 2-Way Car Speakers with Paper Woofer Cones (Pair) - Black"',
#   'brand_id': 31,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 23.99},
#  {'product_id': 23,
#   'product_name': '4TB Red 5400 rpm SATA III 3.5 Internal NAS HDD Retail Kit',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 149.99},
#  {'product_id': 24,
#   'product_name': "AudioQuest - Golden Gate 9.8' RCA-to-RCA Audio Cable - Black/Red",
#   'brand_id': 34,
#   'category_id': 13,
#   'model_year': 2021,
#   'list_price': 89.99},
#  {'product_id': 25,
#   'product_name': 'Toshiba - 3TB Internal Serial ATA III Hard Drive for Desktops',
#   'brand_id': 25,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 139.99},
#  {'product_id': 26,
#   'product_name': 'Logitech - G560 LIGHTSYNC 2.1 Bluetooth Gaming Speakers with Game Driven RGB Lighting (3-Piece) - Black',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 199.99},
#  {'product_id': 27,
#   'product_name': 'Details About *brand New* Pny Anarchy 16gb Kit (2x8gb) Ddr4 2400mhz Pc419200 Desktop Memory',
#   'brand_id': 18,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 98.95},
#  {'product_id': 28,
#   'product_name': 'WI-SP500 Wireless In-Ear Sports Headphones (Black)',
#   'brand_id': 3,
#   'category_id': 14,
#   'model_year': 2021,
#   'list_price': 79.99},
#  {'product_id': 29,
#   'product_name': '251 Outdoor Environmental Speakers (White)',
#   'brand_id': 24,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 398.0},
#  {'product_id': 30,
#   'product_name': 'Sony Mini Digital Video Cassettes - DVC - 1 Hour',
#   'brand_id': 3,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 11.79},
#  {'product_id': 31,
#   'product_name': 'Russound - Acclaim 5 Series 5-1/4 2-Way Indoor/Outdoor Speakers (Pair) - White"',
#   'brand_id': 29,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 142.99},
#  {'product_id': 32,
#   'product_name': 'Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charcoal black',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 74.99},
#  {'product_id': 33,
#   'product_name': 'Circle 2 2MP Wire-Free Network Camera with Night Vision',
#   'brand_id': 4,
#   'category_id': 13,
#   'model_year': 2021,
#   'list_price': 199.99},
#  {'product_id': 34,
#   'product_name': 'Samsung-3-Pack-Connect-Home-Smart-Wi-Fi-System-AC1300',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 239.0},
#  {'product_id': 35,
#   'product_name': 'SRS-ZR7 Wireless Speaker',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 248.0},
#  {'product_id': 36,
#   'product_name': 'SanDisk Extreme 500 Portable SSD 500GB SDSSDEXT-500G-G25',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 199.99},
#  {'product_id': 37,
#   'product_name': 'VE278Q 27 Widescreen LCD Computer Display',
#   'brand_id': 10,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 199.99},
#  {'product_id': 38,
#   'product_name': '1TB T5 Portable Solid-State Drive (Black)',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 349.99},
#  {'product_id': 39,
#   'product_name': 'SRS-XB40 Bluetooth Speaker (Black)',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 148.0},
#  {'product_id': 40,
#   'product_name': 'WD - My Passport X 3TB External USB 3.0 Portable Hard Drive - Black',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 99.99},
#  {'product_id': 41,
#   'product_name': 'Dell - P2418HT 24 IPS LED FHD Touch-Screen Monitor - Black"',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 323.52},
#  {'product_id': 42,
#   'product_name': 'Toshiba - 2.0-Channel Soundbar with 16-Watt Digital Amplifier - Black',
#   'brand_id': 25,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 99.99},
#  {'product_id': 43,
#   'product_name': 'AudioQuest - GOLDG01R Golden Gate 1m (3.28 ft.) RCA Audio Cable - Red',
#   'brand_id': 34,
#   'category_id': 13,
#   'model_year': 2021,
#   'list_price': 68.75},
#  {'product_id': 44,
#   'product_name': 'Lenovo - 300-20ISH 20 All-In-One - Intel Pentium - 4GB Memory - 500GB Hard Drive - Black"',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 449.99},
#  {'product_id': 45,
#   'product_name': 'XPS 8920 Tower Desktop Computer',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 919.99},
#  {'product_id': 46,
#   'product_name': 'Leviathan Elite Gaming Soundbar',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 195.99},
#  {'product_id': 47,
#   'product_name': 'UBD-M9500 HDR UHD Upscaling Blu-ray Disc Player',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2021,
#   'list_price': 399.98},
#  {'product_id': 48,
#   'product_name': 'Sharp - 350W 5-Disc Mini Component System - Black',
#   'brand_id': 32,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 299.87},
#  {'product_id': 49,
#   'product_name': 'Details About Netgear Nighthawk A7000 (ac1900) Dualband Wifi Usb Adapter',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 65.89},
#  {'product_id': 50,
#   'product_name': 'TP-Link AV500 2-port Powerline Starter Kit',
#   'brand_id': 26,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 34.99},
#  {'product_id': 51,
#   'product_name': 'CORSAIR - VOID Surround Hybrid Wired Stereo Gaming Headset for PC, PS4, Xbox One, Nintendo Switch, Mobile devices - Carbon',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 79.99},
#  {'product_id': 52,
#   'product_name': 'Everest Elite 700 Around-Ear Wireless Headphones (White)',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2021,
#   'list_price': 224.99},
#  {'product_id': 53,
#   'product_name': 'AW6500 All-Weather Outdoor Speaker (White, Single)',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 249.98},
#  {'product_id': 54,
#   'product_name': 'Sony LBT-GPX555 Mini-System with Bluetooth and NFC',
#   'brand_id': 3,
#   'category_id': 7,
#   'model_year': 2021,
#   'list_price': 324.99},
#  {'product_id': 55,
#   'product_name': 'Toshiba Micro Component Speaker System: Wireless Bluetooth Speaker Sound System with FM',
#   'brand_id': 25,
#   'category_id': 7,
#   'model_year': 2021,
#   'list_price': 89.99},
#  {'product_id': 56,
#   'product_name': 'Prime Three-Way Center Channel Speaker (Premium Black Ash)',
#   'brand_id': 36,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 349.99},
#  {'product_id': 57,
#   'product_name': 'CORSAIR - AX760 760-Watt ATX Power Supply - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 179.99},
#  {'product_id': 58,
#   'product_name': 'Samsung - 960 Pro 1TB Internal PCI Express 3.0 x4 (NVMe 1.1) Solid State Drive',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 617.99},
#  {'product_id': 59,
#   'product_name': 'Klipsch - Reference Soundbar with 10 Wireless Subwoofer - Black"',
#   'brand_id': 27,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 799.99},
#  {'product_id': 60,
#   'product_name': 'Details About Microsoft Arc Mouse Bluetooth 4.0 Souris Wireless For Surface Windows 10',
#   'brand_id': 16,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 79.99},
#  {'product_id': 61,
#   'product_name': 'DENAQ - 8-Cell Lithium-Ion Battery for Select HP Pavilion Laptops',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 82.99},
#  {'product_id': 62,
#   'product_name': 'The Rebel BT On-Ear Wireless Bluetooth Headphones (Black)',
#   'brand_id': 20,
#   'category_id': 14,
#   'model_year': 2021,
#   'list_price': 39.99},
#  {'product_id': 63,
#   'product_name': 'NETGEAR AC1000 Dual Band Smart WiFi Router',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 54.99},
#  {'product_id': 64,
#   'product_name': 'LG - 75 Class - LED - UJ6470 Series - 2160p - Smart - 4K UHD TV with HDR"',
#   'brand_id': 15,
#   'category_id': 1,
#   'model_year': 2021,
#   'list_price': 2299.99},
#  {'product_id': 65,
#   'product_name': 'Apple - Pre-Owned iPad 3 - 32GB - White',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 219.99},
#  {'product_id': 66,
#   'product_name': 'Yamaha - MusicCast 5.1-Ch. 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2021,
#   'list_price': 599.95},
#  {'product_id': 67,
#   'product_name': 'SVS - Prime Dual 5-1/4 Passive 3-Way Center-Channel Speaker - Gloss piano black"',
#   'brand_id': 36,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 449.98},
#  {'product_id': 68,
#   'product_name': 'Lenovo - 510-23ISH 23 Touch-Screen All-In-One - Intel Core i5 - 8GB Memory - 2TB Hard Drive - Black"',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 849.99},
#  {'product_id': 69,
#   'product_name': 'Alpine - 6 x 9" 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black"',
#   'brand_id': 35,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 54.99},
#  {'product_id': 70,
#   'product_name': 'NS-IW480CWH In-Ceiling 8 Natural Sound Three-Way Speaker System (Pair)',
#   'brand_id': 5,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 124.95},
#  {'product_id': 71,
#   'product_name': 'Logitech Ultrathin Touch Mouse T630 for Windows 8 Touch Gestures',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 29.99},
#  {'product_id': 72,
#   'product_name': 'Samsung Radiant360 R1 Wi-Fi/Bluetooth Speaker WAM1500/ZA - Black (Certified Refurbished)',
#   'brand_id': 1,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 71.99},
#  {'product_id': 73,
#   'product_name': 'Logitech Focus Case with Integrated Keyboard for iPad Mini 4, Dark Blue',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 68.99},
#  {'product_id': 74,
#   'product_name': '32GB High Speed UHS-I SDHC U3 Memory Card (Class 10)',
#   'brand_id': 3,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 33.79},
#  {'product_id': 75,
#   'product_name': 'ProSafe 16-Port Gigabit Desktop Switch',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 79.99},
#  {'product_id': 76,
#   'product_name': 'WD - Se 2TB Internal Serial ATA Hard Drive for Desktops (OEM/Bare Drive)',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 455.9},
#  {'product_id': 77,
#   'product_name': 'TP-Link Archer T9E AC1900 Wireless WiFi PCIe network Adapter Card for PC',
#   'brand_id': 26,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 69.99},
#  {'product_id': 78,
#   'product_name': '151 SE Outdoor Environmental Speakers (White)',
#   'brand_id': 24,
#   'category_id': 5,
#   'model_year': 2021,
#   'list_price': 278.0},
#  {'product_id': 79,
#   'product_name': 'JBL Everest 710 Silver Over-Ear Wireless Bluetooth Headphones (Silver)',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2021,
#   'list_price': 249.99},
#  {'product_id': 80,
#   'product_name': 'Acer - 2-in-1 15.6 Refurbished Touch-Screen Laptop - Intel Core i7 - 12GB Memory - NVIDIA GeForce 940MX - 1TB Hard Drive - Steel gray"',
#   'brand_id': 38,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 809.99},
#  {'product_id': 81,
#   'product_name': 'Samsung - 960 EVO 500GB Internal PCI Express 3.0 x4 (NVMe) Solid State Drive for Laptops',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 234.59},
#  {'product_id': 82,
#   'product_name': 'Acer Aspire E5-574-53QS 15.6 LED Notebook - Intel Core i5 (6th Gen) i5-6200U Dual-core (2 Core) 2.30 GHz - 4 GB DDR3L SDRAM RAM - 1 TB HDD - DVD-Writer - Intel HD Graphics 550 DDR3L SDRAM - Wind"',
#   'brand_id': 38,
#   'category_id': 4,
#   'model_year': 2021,
#   'list_price': 389.99},
#  {'product_id': 83,
#   'product_name': 'Logitech Circle Black Portable Wifi Video Monitoring Camera Webcam',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 159.99},
#  {'product_id': 84,
#   'product_name': 'Samsung - 850 PRO 1TB Internal SATA III Solid State Drive for Laptops',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 479.99},
#  {'product_id': 85,
#   'product_name': 'Samsung - 40 Class (39.5" Diag.) - LED - 1080p - Smart - HDTV"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 397.99},
#  {'product_id': 86,
#   'product_name': 'Details About Razer Kraken Pro V2 Analog Gaming Headset For Pc/xbox One/ps4 Black (p05)',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 52.95},
#  {'product_id': 87,
#   'product_name': 'Alpine - 6-1/2 2-Way Component Car Speakers with Poly-Mica Cones (Pair) - Black"',
#   'brand_id': 35,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 100.99},
#  {'product_id': 88,
#   'product_name': 'SanDisk - Ultra 500GB Internal SATA Solid State Drive for Laptops',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 89,
#   'product_name': 'Definitive Technology - Disappearing Dual 6-1/2 In-Wall Speaker (Each) - Black"',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 549.99},
#  {'product_id': 90,
#   'product_name': 'Razer - Blade Pro 17.3 4K Ultra HD Touch-Screen Laptop - Intel Core i7 - 32GB Memory - NVIDIA GeForce GTX 1080 - 1TB SSD - Black"',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 3989.99},
#  {'product_id': 91,
#   'product_name': 'Sennheiser - Earbud Headphones - Black',
#   'brand_id': 30,
#   'category_id': 11,
#   'model_year': 2018,
#   'list_price': 799.98},
#  {'product_id': 92,
#   'product_name': 'Sony - WH-CH700N Wireless Noise Canceling Over-the-Ear Headphones - Black',
#   'brand_id': 3,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 93,
#   'product_name': 'Logitech iPad Pro 12.9 inch Keyboard Case SLIM COMBO with Detachable',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 118.99},
#  {'product_id': 94,
#   'product_name': '128GB iPod touch (Space Gray) (6th Generation)',
#   'brand_id': 2,
#   'category_id': 6,
#   'model_year': 2018,
#   'list_price': 349.99},
#  {'product_id': 95,
#   'product_name': 'Apple iPod Touch 128GB Blue',
#   'brand_id': 2,
#   'category_id': 6,
#   'model_year': 2018,
#   'list_price': 349.99},
#  {'product_id': 96,
#   'product_name': 'Logitech - Harmony Home Hub - Black',
#   'brand_id': 4,
#   'category_id': 13,
#   'model_year': 2018,
#   'list_price': 99.99},
#  {'product_id': 97,
#   'product_name': 'Razer BlackShark Over Ear Noise Isolating PC Gaming Headset - Metal Construction and Compatible with PS4',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 112.99},
#  {'product_id': 98,
#   'product_name': 'DENAQ - AC Power Adapter and Charger for Select Dell Inspiron and Latitude Laptops - Black',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 20.99},
#  {'product_id': 99,
#   'product_name': 'MCR-B043 30W Bluetooth Wireless Music System (Red)',
#   'brand_id': 5,
#   'category_id': 10,
#   'model_year': 2018,
#   'list_price': 249.99},
#  {'product_id': 100,
#   'product_name': 'Pro-Series 49-Class Full HD Outdoor LED TV (Silver)',
#   'brand_id': 22,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 4295.98},
#  {'product_id': 101,
#   'product_name': 'HD 4.40 BT Wireless Bluetooth Headphones',
#   'brand_id': 30,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 149.95},
#  {'product_id': 102,
#   'product_name': 'Yamaha - Micro Component System - Blue',
#   'brand_id': 5,
#   'category_id': 10,
#   'model_year': 2018,
#   'list_price': 264.99},
#  {'product_id': 103,
#   'product_name': 'Details About Netgear 16 X 4 Docsis 3.0 Cable Modem Black',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 129.99},
#  {'product_id': 104,
#   'product_name': 'Sony - High Power XB60 Portable Bluetooth Speaker - Black',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 349.99},
#  {'product_id': 105,
#   'product_name': 'Under Armour Sport Wireless Flex Neckband In-Ear Headphones',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 129.95},
#  {'product_id': 106,
#   'product_name': 'Lenovo Flex 4 1470 80SA0000US 2-in-1 - 14 HD Touch - Pentium 4405U 2.1Ghz - 4GB - 500GB"',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 303.99},
#  {'product_id': 107,
#   'product_name': 'PNY Performance 8GB Kit (2x4GB) DDR3 1600MHz (PC3-12800) CL11 Desktop Memory - MD8GK2D31600NHS-Z',
#   'brand_id': 18,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 47.95},
#  {'product_id': 108,
#   'product_name': 'DENAQ - AC Power Adapter and Charger for Select Toshiba Satellite Laptops - Black',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 27.99},
#  {'product_id': 109,
#   'product_name': 'CORSAIR - MM800 Polaris RGB Gaming Mouse Pad - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 49.99},
#  {'product_id': 110,
#   'product_name': 'Lenovo Yoga Mouse',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 54.99},
#  {'product_id': 111,
#   'product_name': "AudioQuest - Black Lab 16.4' In-Wall Subwoofer Cable - Black/White",
#   'brand_id': 34,
#   'category_id': 13,
#   'model_year': 2018,
#   'list_price': 49.99},
#  {'product_id': 112,
#   'product_name': 'JBL Under Armour Sport Wireless Heart Rate In-Ear Headphones Black',
#   'brand_id': 7,
#   'category_id': 11,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 113,
#   'product_name': 'JBL - Free True Wireless In-Ear Headphones - Black',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 129.95},
#  {'product_id': 114,
#   'product_name': 'Pioneer - Elite 7.2-Ch. Hi-Res 4K Ultra HD HDR Compatible A/V Home Theater Receiver - Black',
#   'brand_id': 17,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 499.0},
#  {'product_id': 115,
#   'product_name': 'SunBriteTV - Outdoor Tilting TV Wall Mount for Most 37 - 80" TVs - Powder coated black"',
#   'brand_id': 22,
#   'category_id': 13,
#   'model_year': 2018,
#   'list_price': 149.98},
#  {'product_id': 116,
#   'product_name': 'My Cloud Expert Series EX4100 24TB 4-Bay NAS Server (4 x 6TB)',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 1449.0},
#  {'product_id': 117,
#   'product_name': 'CORSAIR - VENGEANCE RGB Series 32GB (4PK 8GB) 3.466GHz DDR4 Desktop Memory with RGB Lighting - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 359.99},
#  {'product_id': 118,
#   'product_name': 'Marantz - SR 9.2-Ch. Hi-Res With HEOS 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 28,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 2199.98},
#  {'product_id': 119,
#   'product_name': 'Yamaha - Natural Sound 5 2-Way All-Weather Outdoor Speakers (Pair) - White"',
#   'brand_id': 5,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 87.99},
#  {'product_id': 120,
#   'product_name': 'GTK-XB90 Bluetooth Speaker',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 449.99},
#  {'product_id': 121,
#   'product_name': 'RX-V583 7.2-Channel Network A/V Receiver',
#   'brand_id': 5,
#   'category_id': 7,
#   'model_year': 2018,
#   'list_price': 429.99},
#  {'product_id': 122,
#   'product_name': 'Kenwood CD Single DIN In-Dash Bluetooth Car Stereo Receiver KDC-BT365U',
#   'brand_id': 31,
#   'category_id': 15,
#   'model_year': 2018,
#   'list_price': 83.99},
#  {'product_id': 123,
#   'product_name': 'SP-C22 Andrew Jones Designed Center Channel Speaker',
#   'brand_id': 17,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 99.99},
#  {'product_id': 124,
#   'product_name': 'MU8000-Series 65-Class HDR UHD Smart LED TV',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 1597.99},
#  {'product_id': 125,
#   'product_name': 'CORSAIR - HD Series 120mm Case Cooling Fan Kit with RGB lighting',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 76.99},
#  {'product_id': 126,
#   'product_name': 'Samsung - 960 PRO 512GB Internal PCI Express 3.0 x4 (NVMe) Solid State Drive for Laptops',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 329.99},
#  {'product_id': 127,
#   'product_name': 'JBL Inspire 700 In-Ear Wireless Sport Headphones with Charging Case (Black)',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 54.0},
#  {'product_id': 128,
#   'product_name': 'NETGEAR Nighthawk AC1900 VDSL/ADSL Modem Router Certified with CenturyLink - Non-bonded',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 249.99},
#  {'product_id': 129,
#   'product_name': 'CORSAIR - VENGEANCE LED Series 16GB (2PK 8GB) 3.0GHz DDR4 Desktop Memory with LED Lighting - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 203.99},
#  {'product_id': 130,
#   'product_name': 'Alpine Electronics PWE-S8-WRA Powered Subwoofer for 2011-Up Jeep Wrangler',
#   'brand_id': 35,
#   'category_id': 8,
#   'model_year': 2018,
#   'list_price': 499.95},
#  {'product_id': 131,
#   'product_name': 'HP 15-AY103DX 15.6 Touchscreen Touch Screen HD Laptop Notebook PC Computer 7th Gen i5-7200U Kaby Lake 8GB Memory 1TB HDD Hard Drive Windows 10"',
#   'brand_id': 39,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 429.99},
#  {'product_id': 132,
#   'product_name': 'Apple MD825AM/A Lightning to VGA Adapter for iPhones',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 48.99},
#  {'product_id': 133,
#   'product_name': 'Sony - 55 Class - OLED - A1E Series - 2160p - Smart - 4K UHD TV with HDR"',
#   'brand_id': 3,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 2998.0},
#  {'product_id': 134,
#   'product_name': 'CORSAIR - Vengeance Pro Series 16GB (2PK x 8GB) 1.6 GHz DDR3 DIMM Desktop Memory Kit - Multi',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 149.99},
#  {'product_id': 135,
#   'product_name': 'Logitech - Harmony 950 Universal Remote - Black',
#   'brand_id': 4,
#   'category_id': 13,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 136,
#   'product_name': 'Details About Razer Cynosa Chroma Rgb Gaming Keyboard Spillresistant Durable Design',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 58.99},
#  {'product_id': 137,
#   'product_name': 'Logitech - Harmony 665 10-Device Universal Remote - Black',
#   'brand_id': 4,
#   'category_id': 13,
#   'model_year': 2018,
#   'list_price': 49.99},
#  {'product_id': 138,
#   'product_name': 'Details About Razer Blade Laptop 14 Full Hd (i77700hq"',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 1269.99},
#  {'product_id': 139,
#   'product_name': 'CORSAIR - Vengeance 16 GB (2PK x 8GB) 1.6 GHz DDR3 DIMM Desktop Memory Kit - Multi',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 169.0},
#  {'product_id': 140,
#   'product_name': '12 MacBook (Mid 2017, Gold)',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 1503.99},
#  {'product_id': 141,
#   'product_name': 'Seagate Backup Plus Ultra Slim 2TB Portable External Hard Drive',
#   'brand_id': 14,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 98.99},
#  {'product_id': 142,
#   'product_name': 'Yamaha - AVENTAGE 7.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 439.99},
#  {'product_id': 143,
#   'product_name': 'CORSAIR - Vengeance LPX 32GB (2PK x 16GB) 2.6 GHz DDR4 DRAM Desktop Memory Kit - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 284.99},
#  {'product_id': 144,
#   'product_name': 'Dell - XPS 2-in-1 13.3 Touch-Screen Laptop - Intel Core i7 - 16GB Memory - 256GB Solid State Drive - Silver"',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 979.99},
#  {'product_id': 145,
#   'product_name': 'Klipsch AW-4i In-Ear Headphones',
#   'brand_id': 27,
#   'category_id': 11,
#   'model_year': 2018,
#   'list_price': 59.0},
#  {'product_id': 146,
#   'product_name': 'Russound - Acclaim 5 Series 6-1/2 2-Way Indoor/Outdoor Speakers (Pair) - White"',
#   'brand_id': 29,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 116.64},
#  {'product_id': 147,
#   'product_name': 'LG - 65 Class - LED - SJ8500 Series - 2160p - Smart - 4K UHD TV with HDR"',
#   'brand_id': 15,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 1599.52},
#  {'product_id': 148,
#   'product_name': 'Seagate - Backup Plus 5TB External USB 3.0 Portable Hard Drive - silver',
#   'brand_id': 14,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 139.99},
#  {'product_id': 149,
#   'product_name': 'ASUS VivoBook Max X541SA 15.6Inch Laptop Intel Pentium 4GB Memory 500GB HD Matte IMR X541SA-PD0703X',
#   'brand_id': 10,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 229.99},
#  {'product_id': 150,
#   'product_name': 'Sharp - 5-Disc Micro System - Black',
#   'brand_id': 32,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 179.99},
#  {'product_id': 151,
#   'product_name': 'Apple - Pre-Owned iPad mini 4 - 16GB - Space gray',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 319.99},
#  {'product_id': 152,
#   'product_name': 'Corsair CMY32GX3M4A1600C9 Vengeance Pro 32GB (4x8GB) DDR3 1600 MHz (PC3 12800) Desktop 1.5V',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 234.99},
#  {'product_id': 153,
#   'product_name': '1TB WD Black Mobile OEM Hard Drive (WD10JPLX)',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 64.99},
#  {'product_id': 154,
#   'product_name': 'SVS - 12 800W Powered Subwoofer - Black oak veneer"',
#   'brand_id': 36,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 1399.98},
#  {'product_id': 155,
#   'product_name': "AudioQuest - RJE Vodka 2.5' Ethernet Cable - Black/Blue",
#   'brand_id': 34,
#   'category_id': 7,
#   'model_year': 2018,
#   'list_price': 249.99},
#  {'product_id': 156,
#   'product_name': 'Details About Logitech Ue Roll 2 Wireless Portable Bluetooth Waterproof Speaker',
#   'brand_id': 4,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 69.99},
#  {'product_id': 157,
#   'product_name': 'JBL Flip 3 Splashproof Portable Bluetooth Speaker (Teal)',
#   'brand_id': 7,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 459.98},
#  {'product_id': 158,
#   'product_name': 'SRS-XB40 Bluetooth Speaker (Blue)',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 110.99},
#  {'product_id': 159,
#   'product_name': 'Samsung - 960 EVO 250GB Internal PCI Express 3.0 x4 (NVMe) Solid State Drive for Laptops',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 117.6},
#  {'product_id': 160,
#   'product_name': 'Lenovo - Yoga 710 2-in-1 11.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - 128GB Solid State Drive - Silver Tablet PC Notebook 80V6000PUS"',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 573.99},
#  {'product_id': 161,
#   'product_name': 'Veranda Series 55-Class UHD Outdoor LED TV',
#   'brand_id': 22,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 1999.99},
#  {'product_id': 162,
#   'product_name': 'JBL Everest 310 On-Ear Wireless Bluetooth Headphones (Gun Metal)',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 179.99},
#  {'product_id': 163,
#   'product_name': 'NETGEAR Nighthawk X10 AD7200 802.11ac/ad Quad-Stream WiFi Router',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 390.99},
#  {'product_id': 164,
#   'product_name': 'HT-XT2 170W 2.1-Channel TV Speaker Base (Black)',
#   'brand_id': 3,
#   'category_id': 7,
#   'model_year': 2018,
#   'list_price': 81.99},
#  {'product_id': 165,
#   'product_name': 'Lenovo - YOGA Wireless Optical Mouse - Black',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 29.95},
#  {'product_id': 166,
#   'product_name': 'AVENTAGE RX-A1070 7.2-Channel Network A/V Receiver',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 1199.98},
#  {'product_id': 167,
#   'product_name': "AudioQuest - Golden Gate 6.6' Analog RCA Cable - Red",
#   'brand_id': 34,
#   'category_id': 13,
#   'model_year': 2018,
#   'list_price': 79.98},
#  {'product_id': 168,
#   'product_name': 'MCR-B043 30W Bluetooth Wireless Music System (Black)',
#   'brand_id': 5,
#   'category_id': 10,
#   'model_year': 2018,
#   'list_price': 232.99},
#  {'product_id': 169,
#   'product_name': 'Signature Series 43-Class UHD Outdoor LED TV (Black)',
#   'brand_id': 22,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 2799.99},
#  {'product_id': 170,
#   'product_name': 'Disappearing Series DI 5.5S 2-Way Speaker (Single, 5.25 Driver)',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 249.98},
#  {'product_id': 171,
#   'product_name': 'SVS - 12 800W Powered Subwoofer - Gloss piano black"',
#   'brand_id': 36,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 1399.98},
#  {'product_id': 172,
#   'product_name': 'SanDisk - 120GB Internal SATA Solid State Drive for Laptops',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 48.99},
#  {'product_id': 173,
#   'product_name': 'Marantz - NR 250W 5.2-Ch. Hi-Res With HEOS 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 28,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 549.0},
#  {'product_id': 174,
#   'product_name': '64GB High Speed UHS-I SDXC U3 Memory Card (Class 10)',
#   'brand_id': 3,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 51.99},
#  {'product_id': 175,
#   'product_name': 'CORSAIR - ML Series 140mm Case Cooling Fan - White',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 29.85},
#  {'product_id': 176,
#   'product_name': 'Yamaha RX-V383BL 5.1-Channel 4K Ultra HD AV Receiver with Bluetooth',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 234.99},
#  {'product_id': 177,
#   'product_name': 'SanDisk Ultra II 500GB SATA III SSD - 2.5-Inch 7mm Height Solid State Drive - SDSSDHII-500G-G25',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 155.47},
#  {'product_id': 178,
#   'product_name': 'Crystal 460X RGB Mid-Tower Case',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 179,
#   'product_name': '128GB iPod touch (Gold) (6th Generation)',
#   'brand_id': 2,
#   'category_id': 6,
#   'model_year': 2018,
#   'list_price': 359.99},
#  {'product_id': 180,
#   'product_name': 'Refurbished Samsung Curved 65 4K (2160P) Smart QLED TV (2017 Model) + 1 Year Extended Warranty (QN65Q7CAMFXZA)"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 3137.95},
#  {'product_id': 181,
#   'product_name': 'AS-5i Pro Sport Earphones (Blue)',
#   'brand_id': 27,
#   'category_id': 11,
#   'model_year': 2018,
#   'list_price': 79.0},
#  {'product_id': 182,
#   'product_name': 'WD 4TB My Cloud Home Personal Cloud Storage - WDBVXC0040HWT-NESN',
#   'brand_id': 37,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 165.99},
#  {'product_id': 183,
#   'product_name': 'Sony - WF 1000X True Wireless In-Ear Noise Canceling Headphones - Black',
#   'brand_id': 3,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 178.0},
#  {'product_id': 184,
#   'product_name': 'MU9000-Series 65-Class HDR UHD Smart LED TV',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 1949.52},
#  {'product_id': 185,
#   'product_name': 'Samsung 860 EVO 500GB 2.5 Inch SATA III Internal SSD (MZ-76E500B/AM)',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 143.99},
#  {'product_id': 186,
#   'product_name': 'XBR-X850E-Series 75-Class HDR UHD Smart LED TV',
#   'brand_id': 3,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 2498.0},
#  {'product_id': 187,
#   'product_name': 'CORSAIR - VENGEANCE Series 16GB (2PK 8GB) 2.4GHz DDR4 Laptop Memory - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 179.99},
#  {'product_id': 188,
#   'product_name': 'Pioneer - Elite 7.2-Ch. Hi-Res 4K Ultra HD HDR Compatible A/V Home Theater Receiver - Black',
#   'brand_id': 17,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 499.98},
#  {'product_id': 189,
#   'product_name': "Razer ManO'War Wireless 7.1 Surround Sound Gaming Headset (Black) Man O War READ",
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 169.99},
#  {'product_id': 190,
#   'product_name': '4TB Network OEM HDD Retail Kit (8-Pack, WD40EFRX, Red Drives)',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 140.45},
#  {'product_id': 191,
#   'product_name': 'CORSAIR - VOID PRO RGB Wireless Dolby 7.1-Channel Surround Sound Gaming Heads...',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 99.99},
#  {'product_id': 192,
#   'product_name': 'Get Up Stand Bluetooth Home Audio System',
#   'brand_id': 20,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 249.99},
#  {'product_id': 193,
#   'product_name': 'CORSAIR HYDRO SERIES H100i v2 AIO Liquid CPU Cooler',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 138.19},
#  {'product_id': 194,
#   'product_name': 'h.ear go Wireless Speaker (Viridian Blue)',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 189.99},
#  {'product_id': 195,
#   'product_name': 'Sony - SF-UY2 Series 64GB SDXC UHS-I Memory Card',
#   'brand_id': 3,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 72.99},
#  {'product_id': 196,
#   'product_name': 'Definitive Technology - SuperCube 4000 8 1200-Watt Powered Subwoofer - Black"',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 799.98},
#  {'product_id': 197,
#   'product_name': 'CORSAIR - VENGEANCE LED Series 16GB (2PK 8GB) 2.4GHz DDR4 Desktop Memory with LED Lighting - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 161.99},
#  {'product_id': 198,
#   'product_name': 'Russound - Acclaim 5 Series 100W 2-Way Indoor/Outdoor Speakers (Pair) - Black',
#   'brand_id': 29,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 199,
#   'product_name': "AudioQuest - RJE Cinnamon 2.5' Ethernet Cable - Black/Red",
#   'brand_id': 34,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 75.99},
#  {'product_id': 200,
#   'product_name': 'Razer Naga Chroma MMO Gaming Mouse 12 Programmable Thumb Buttons 16000 DPI Wired',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 58.99},
#  {'product_id': 201,
#   'product_name': 'Details About Fits Chevy Silverado Pickup 19992006 Speaker Upgrade Pioneer Tsg1345r Tsg4620s',
#   'brand_id': 17,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 33.49},
#  {'product_id': 202,
#   'product_name': '480GB Extreme Pro Solid State Drive',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 219.99},
#  {'product_id': 203,
#   'product_name': 'JBL - 6-1/2 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black"',
#   'brand_id': 7,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 79.99},
#  {'product_id': 204,
#   'product_name': 'DENAQ - AC Adapter for SONY PCG Series',
#   'brand_id': 23,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 23.99},
#  {'product_id': 205,
#   'product_name': 'Definitive Technology - Mythos 2-way 175 W Speaker - Pack of 1 - Black',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 399.0},
#  {'product_id': 206,
#   'product_name': 'Details About Sony Kd43x720e 43inch 4k Ultra Hd Smart Led Tv (2017 Model) Kd43x720e',
#   'brand_id': 3,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 598.0},
#  {'product_id': 207,
#   'product_name': 'RE270K AC750 Wi-Fi Range Extender with Smart Plug',
#   'brand_id': 26,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 69.98},
#  {'product_id': 208,
#   'product_name': 'Details About Wd Red Pro 8tb Nas Desktop Hard Drive Intellipower 6 Gbs 128 Mb Cache Wd8001ffwx',
#   'brand_id': 37,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 322.99},
#  {'product_id': 209,
#   'product_name': 'Dell DW316 External USB Slim DVD R/W Optical Drive 429-AAUX',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 43.96},
#  {'product_id': 210,
#   'product_name': 'Details About Logitech G403 Prodigy Wireless Gaming Mouse',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 99.99},
#  {'product_id': 211,
#   'product_name': 'Marantz - NR 350W 7.2-Ch. Hi-Res With HEOS 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 28,
#   'category_id': 7,
#   'model_year': 2018,
#   'list_price': 749.0},
#  {'product_id': 212,
#   'product_name': '15.4 MacBook Pro with Touch Bar (Late 2016, Space Gray)',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 2.0},
#  {'product_id': 213,
#   'product_name': 'Toshiba - 2TB Internal SATA Hard Drive for Desktops',
#   'brand_id': 25,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 83.31},
#  {'product_id': 214,
#   'product_name': 'NETGEAR GS116E-200NAS / NETGEAR ProSafe Plus GS116Ev2 - Switch - unmanaged - 16 x 10/100/1000 - desktop',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 159.99},
#  {'product_id': 215,
#   'product_name': 'Details About Netgear Modem Vdsl/adsl Broadband High Speed Dsl Dm200 Verizon At&t Used!',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 59.99},
#  {'product_id': 216,
#   'product_name': 'Sharp - 50W Executive Hi-Fi Component System - Black',
#   'brand_id': 32,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 149.99},
#  {'product_id': 217,
#   'product_name': 'HP - Bluetooth Laser Mouse - Black',
#   'brand_id': 18,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 22.06},
#  {'product_id': 218,
#   'product_name': 'Samsung - Adaptive Fast Charging Wall Charger - White',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 7.99},
#  {'product_id': 219,
#   'product_name': 'Sennheiser CX 7.00BT Wireless In-Ear Headphone',
#   'brand_id': 30,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 149.99},
#  {'product_id': 220,
#   'product_name': 'JBL Reflect Contour 2 Wireless Sport In-Ear Headphones with Three-Button Remote and Microphone (Blue)',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 99.99},
#  {'product_id': 221,
#   'product_name': 'SanDisk Ultra II 1TB SATA III SSD - 2.5-Inch 7mm Height Solid State Drive - SDSSDHII-1T00-G25',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 307.99},
#  {'product_id': 222,
#   'product_name': 'Yamaha - AVENTAGE 7.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 899.98},
#  {'product_id': 223,
#   'product_name': 'NS-PA40 5.1-Channel Speaker System (Black)',
#   'brand_id': 5,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 349.99},
#  {'product_id': 224,
#   'product_name': 'R-S300 Natural Sound Stereo Receiver',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2018,
#   'list_price': 271.99},
#  {'product_id': 225,
#   'product_name': 'SanDisk - Extreme PRO 64GB SDXC UHS-II Memory Card',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 199.99},
#  {'product_id': 226,
#   'product_name': 'CORSAIR - Vengeance LPX 16GB (2PK x 8GB) 3.2 GHz DDR4 DRAM Desktop Memory Kit - Black',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 169.99},
#  {'product_id': 227,
#   'product_name': 'Definitive Technology - Wireless Audio Adapter - Black/Silver',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 399.98},
#  {'product_id': 228,
#   'product_name': 'Sharp Aquos N7000 65 Class 4K Ultra WiFi Smart LED HDTV"',
#   'brand_id': 32,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 1250.59},
#  {'product_id': 229,
#   'product_name': 'WD - My Book 6TB External USB 3.0 Hard Drive - Black',
#   'brand_id': 37,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 169.99},
#  {'product_id': 230,
#   'product_name': 'SAMSUNG 65 Class 4K (2160P) Ultra HD Smart QLED HDR TV QN65Q6FNAFXZA (2018 Model)"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 2197.99},
#  {'product_id': 231,
#   'product_name': 'Bose SoundLink Color Bluetooth Speaker (Black)',
#   'brand_id': 24,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 89.0},
#  {'product_id': 232,
#   'product_name': 'Sennheiser - CX 3.00 Earbud Headphones - Red',
#   'brand_id': 30,
#   'category_id': 11,
#   'model_year': 2018,
#   'list_price': 33.99},
#  {'product_id': 233,
#   'product_name': 'Samsung - 49 Class (48.5" Diag.) - LED - 1080p - Smart - HDTV"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 431.99},
#  {'product_id': 234,
#   'product_name': 'Lenovo - 100S-14IBR 14 Laptop - Intel Celeron - 2GB Memory - 32GB eMMC Flash Memory - Navy blue"',
#   'brand_id': 13,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 174.99},
#  {'product_id': 235,
#   'product_name': 'TL-SG108 8-Port 10/100/1000 Mbps Unmanaged Desktop Switch',
#   'brand_id': 26,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 24.99},
#  {'product_id': 236,
#   'product_name': 'Sony MDR-1000X/C Wireless Bluetooth Noise Cancelling Hi-Fi Headphones (Certified Refurbished)',
#   'brand_id': 3,
#   'category_id': 14,
#   'model_year': 2018,
#   'list_price': 328.0},
#  {'product_id': 237,
#   'product_name': 'Apple MNF72LL/A 61W USB-C Power Adapter',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 69.0},
#  {'product_id': 238,
#   'product_name': 'Logitech G433 7.1 Wired Gaming Headset with DTS Headphone: X 7.1 Surround for PC',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 78.99},
#  {'product_id': 239,
#   'product_name': 'Pioneer 200W 4x6 Inch 3 Way 4 Ohms Coaxial Car Audio Speakers Pair | TS-A4676R',
#   'brand_id': 17,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 48.99},
#  {'product_id': 240,
#   'product_name': 'WD 8TB My Cloud EX2 Ultra Network Attached Storage - NAS - WDBVBZ0080JCH-NESN',
#   'brand_id': 37,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 394.99},
#  {'product_id': 241,
#   'product_name': 'JBL Trip Visor Mount Portable Bluetooth Hands-Free Kit (Black)',
#   'brand_id': 7,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 99.99},
#  {'product_id': 242,
#   'product_name': 'SanDisk 8GB Clip Jam MP3 Player (Pink)',
#   'brand_id': 9,
#   'category_id': 6,
#   'model_year': 2018,
#   'list_price': 34.99},
#  {'product_id': 243,
#   'product_name': 'CORSAIR - ValueSelect 16GB (2PK x 8GB) 1.3 GHz DDR3 SDRAM Laptop Memory - Multi',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 112.99},
#  {'product_id': 244,
#   'product_name': 'R6i In-Ear Headphones (Black)',
#   'brand_id': 27,
#   'category_id': 11,
#   'model_year': 2018,
#   'list_price': 64.95},
#  {'product_id': 245,
#   'product_name': 'PA248Q 24 LED Backlit IPS Widescreen Monitor',
#   'brand_id': 10,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 322.99},
#  {'product_id': 246,
#   'product_name': 'Definitive Technology - DT Series 6.5 2-Way In-Ceiling Speaker (Each) - Black"',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2018,
#   'list_price': 181.99},
#  {'product_id': 247,
#   'product_name': "AudioQuest - RJE Cinnamon 4.9' Ethernet Cable - Black/Red",
#   'brand_id': 34,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 89.95},
#  {'product_id': 248,
#   'product_name': 'SunBriteTV - Signature Series - 43 Class - LED - Outdoor - Partial Sun - 2160p - 4K UHD TV with HDR"',
#   'brand_id': 22,
#   'category_id': 1,
#   'model_year': 2018,
#   'list_price': 2799.99},
#  {'product_id': 249,
#   'product_name': 'AX860i Digital ATX 860W Power Supply',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2018,
#   'list_price': 209.99},
# ...
#  {'product_id': 437,
#   'product_name': 'JBL Clip2 Portable Speaker',
#   'brand_id': 7,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 39.99},
#  {'product_id': 438,
#   'product_name': 'Apple - iPad Pro 12.9-inch (Latest Model) with Wi-Fi + Cellular - 512 GB - Gold',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 1279.99},
#  {'product_id': 439,
#   'product_name': 'Details About Genuine Used Apple 85w Magsafe Power Adapter Mc556ll/b Model A1343 1185cl',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 81.89},
#  {'product_id': 440,
#   'product_name': 'Samsung - 88 Class - LED - Q9F Series - 2160p - Smart - 4K UHD TV with HDR"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 16999.95},
#  {'product_id': 441,
#   'product_name': 'Chant Sport BT Portable Audio System (Natural)',
#   'brand_id': 20,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 78.0},
#  {'product_id': 442,
#   'product_name': 'Sony - 49 Class - LED - X900E Series - 2160p - Smart - 4K UHD TV with HDR"',
#   'brand_id': 3,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 898.0},
#  {'product_id': 443,
#   'product_name': 'JBL - Everest 110 Wireless In-Ear Headphones - Gunmetal',
#   'brand_id': 7,
#   'category_id': 14,
#   'model_year': 2020,
#   'list_price': 79.99},
#  {'product_id': 444,
#   'product_name': 'Details About Asus Q304 13.3 Laptop I5 2.5 Ghz 6gb 1tb Hdd Win 10 (q304uabhi5t11)"',
#   'brand_id': 10,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 644.52},
#  {'product_id': 445,
#   'product_name': 'Details About Razer Blackwidow Chroma V2',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 103.89},
#  {'product_id': 446,
#   'product_name': 'PNY - 16 GB (2PK x 8GB) 1.6 GHz DDR3L SoDIMM Laptop Memory Kit - Green',
#   'brand_id': 18,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 99.99},
#  {'product_id': 447,
#   'product_name': '12.3 32GB Multi-Touch 2-in-1 Chromebook Plus',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 414.0},
#  {'product_id': 448,
#   'product_name': 'Details About Dell Inspiron I75675650blkpus 15.6 Laptop I57300hq"',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 809.99},
#  {'product_id': 449,
#   'product_name': 'Apple 45W MagSafe 2 Power Adapter for Macbook Air (MD592LL/A)',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 76.99},
#  {'product_id': 450,
#   'product_name': 'Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Space Gray"',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 1499.99},
#  {'product_id': 451,
#   'product_name': '4TB My Book Desktop USB 3.0 External Hard Drive',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 119.99},
#  {'product_id': 452,
#   'product_name': 'Razer Ripsaw USB 3.0 Game Stream and Capture Card for PC',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 125.0},
#  {'product_id': 453,
#   'product_name': 'Dell XPS 15 15.6 4K Touchcreen Laptop Intel i7-6700HQ 16GB 1TB SSD GTX 960M"',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 2379.0},
#  {'product_id': 454,
#   'product_name': 'Kenwood - CD - Built-In Bluetooth - Apple® iPod®- and Satellite Radio-Ready - In-Dash Deck - Black',
#   'brand_id': 31,
#   'category_id': 15,
#   'model_year': 2020,
#   'list_price': 119.66},
#  {'product_id': 455,
#   'product_name': 'SanDisk - Ultra 32GB microSDHC Class 10 Memory Card',
#   'brand_id': 9,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 16.91},
#  {'product_id': 456,
#   'product_name': 'Apple - 21.5 iMac® - Intel Core i5 - 8GB Memory - 1TB Hard Drive - Silver"',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 999.99},
#  {'product_id': 457,
#   'product_name': 'SP-T22A-LR Dolby Atmos-Enabled Add-On Speakers (Pair, Black)',
#   'brand_id': 17,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 199.99},
#  {'product_id': 458,
#   'product_name': 'Polk Audio - SurroundBar 8-Channel Soundbar System with 8 Wireless Subwoofer - Black"',
#   'brand_id': 21,
#   'category_id': 7,
#   'model_year': 2020,
#   'list_price': 799.99},
#  {'product_id': 459,
#   'product_name': 'Polk Audio - SurroundBar 8-Channel Soundbar System with 8 Wireless Subwoofer - Black"',
#   'brand_id': 21,
#   'category_id': 7,
#   'model_year': 2020,
#   'list_price': 699.99},
#  {'product_id': 460,
#   'product_name': 'Polk Audio - SurroundBar 8-Channel Soundbar System with 8 Wireless Subwoofer - Black"',
#   'brand_id': 21,
#   'category_id': 7,
#   'model_year': 2020,
#   'list_price': 799.95},
#  {'product_id': 461,
#   'product_name': 'CORSAIR - Carbide Series Clear® 400C Compact ATX/EATX/Mini-ITX/Micro ATX Mid-Tower Case - White',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 94.99},
#  {'product_id': 462,
#   'product_name': 'PM7005 2-Channel Integrated Amplifier',
#   'brand_id': 28,
#   'category_id': 16,
#   'model_year': 2020,
#   'list_price': 1299.0},
#  {'product_id': 463,
#   'product_name': 'PM7005 2-Channel Integrated Amplifier',
#   'brand_id': 28,
#   'category_id': 16,
#   'model_year': 2020,
#   'list_price': 999.0},
#  {'product_id': 464,
#   'product_name': 'X850F-Series 75-Class HDR UHD Smart LED TV',
#   'brand_id': 3,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 3298.0},
#  {'product_id': 465,
#   'product_name': 'Samsung - Galaxy Tab E - 9.6 - 16GB - Black"',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 197.99},
#  {'product_id': 466,
#   'product_name': 'Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Silver"',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 1972.59},
#  {'product_id': 467,
#   'product_name': 'Russound - 2-Way Outdoor Rock Loudspeaker (Each) - Weathered Granite',
#   'brand_id': 29,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 121.28},
#  {'product_id': 468,
#   'product_name': 'Apple - Smart Cover for Apple iPad and iPad® Air 2 - Charcoal Gray',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 29.95},
#  {'product_id': 469,
#   'product_name': 'Apple - MacBook Pro 13.3 Pre-owned Laptop - Intel Core i5 - 4GB Memory - 320GB - Silver"',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 339.95},
#  {'product_id': 470,
#   'product_name': 'Apple - MacBook Pro 13.3 Pre-owned Laptop - Intel Core i5 - 4GB Memory - 320GB - Silver"',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 576.99},
#  {'product_id': 471,
#   'product_name': 'Details About Razer Basilisk Ergonomic Fps Gaming Mousefast',
#   'brand_id': 11,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 59.99},
#  {'product_id': 472,
#   'product_name': 'Toshiba - 1TB Internal SATA Hard Drive for Laptops',
#   'brand_id': 25,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 52.99},
#  {'product_id': 473,
#   'product_name': 'WD - Blue 500GB Internal SATA Hard Drive',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 49.99},
#  {'product_id': 474,
#   'product_name': 'CORSAIR - DOMINATOR PLATINUM 32GB (2PK 16GB) 3.0GHz DDR4 Desktop Memory with DHX cooling - Black/silver',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 687.0},
#  {'product_id': 475,
#   'product_name': 'CORSAIR - DOMINATOR PLATINUM 32GB (2PK 16GB) 3.0GHz DDR4 Desktop Memory with DHX cooling - Black/silver',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 216.22},
#  {'product_id': 476,
#   'product_name': 'CORSAIR - DOMINATOR PLATINUM 32GB (2PK 16GB) 3.0GHz DDR4 Desktop Memory with DHX cooling - Black/silver',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 293.99},
#  {'product_id': 477,
#   'product_name': 'Yamaha - AVENTAGE 9.2-Ch. 4K Ultra HD A/V Home Theater Receiver - Black',
#   'brand_id': 5,
#   'category_id': 16,
#   'model_year': 2020,
#   'list_price': 1599.98},
#  {'product_id': 478,
#   'product_name': '7.0 Tab A 8GB Tablet (Wi-Fi Only, Black)',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 83.2},
#  {'product_id': 479,
#   'product_name': 'NETGEAR - AC600 Dual-Band WiFi USB Mini Adapter - Black',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 10.99},
#  {'product_id': 480,
#   'product_name': 'Samsung Galaxy Tab E Lite Kids 7; 8 GB Wifi Tablet (White) SM-T113NDWACCC"',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 69.85},
#  {'product_id': 481,
#   'product_name': 'Sony - Premium Jacket Camera Case - Black',
#   'brand_id': 3,
#   'category_id': 9,
#   'model_year': 2020,
#   'list_price': 55.95},
#  {'product_id': 482,
#   'product_name': 'Sony - Premium Jacket Camera Case - Black',
#   'brand_id': 3,
#   'category_id': 9,
#   'model_year': 2020,
#   'list_price': 78.99},
#  {'product_id': 483,
#   'product_name': '391 Series C32F391 32 16:9 Curved FreeSync LCD Monitor',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 349.99},
#  {'product_id': 484,
#   'product_name': 'Chant Mini Portable Bluetooth Wireless Speaker (Navy)',
#   'brand_id': 20,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 39.99},
#  {'product_id': 485,
#   'product_name': 'TL-SG1008P 8-Port Gigabit Desktop Switch with 4-Port PoE',
#   'brand_id': 26,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 66.46},
#  {'product_id': 486,
#   'product_name': 'PNY - XLR8 NVIDIA GeForce GTX 1080 8GB GDDR5X PCI Express 3.0 Graphics Card - Black/Red',
#   'brand_id': 18,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 619.99},
#  {'product_id': 487,
#   'product_name': 'Apple - Pre-owned 9.7-inch iPad Pro - 128GB - Space gray',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 650.99},
#  {'product_id': 488,
#   'product_name': 'Sony 65 Class 4K (2160P) Smart OLED TV (XBR65A1E)"',
#   'brand_id': 3,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 4275.0},
#  {'product_id': 489,
#   'product_name': 'Sony - XB7 Extra Bass Audio System with Bluetooth - Black',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 248.0},
#  {'product_id': 490,
#   'product_name': 'Details About Netgear Cm1000 Docsis 3.1 Ultrahigh Speed Cable Modem',
#   'brand_id': 8,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 171.98},
#  {'product_id': 491,
#   'product_name': 'Samsung - Notebook 5 15.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce 920MX - 1TB Hard Drive - Solid black"',
#   'brand_id': 1,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 799.97},
#  {'product_id': 492,
#   'product_name': '2TB My Passport USB 3.0 Secure Portable Hard Drive (Orange)',
#   'brand_id': 12,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 69.0},
#  {'product_id': 493,
#   'product_name': '27 iMac with Retina 5K Display (Mid 2017)',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 2115.99},
#  {'product_id': 494,
#   'product_name': 'LG Electronics OLED65E6P Flat 65-Inch 4K Ultra HD Smart OLED TV (2016 Model)',
#   'brand_id': 15,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 4296.99},
#  {'product_id': 495,
#   'product_name': 'SRS-ZR5 Wireless Speaker',
#   'brand_id': 3,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 199.99},
#  {'product_id': 496,
#   'product_name': 'Samsung UN65KS9500 65-inch Smart 4K UHD TV',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 2495.0},
#  {'product_id': 497,
#   'product_name': 'Logitech - M570 Wireless Trackball Mouse - Gray/Blue',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 41.98},
#  {'product_id': 498,
#   'product_name': 'Logitech - M570 Wireless Trackball Mouse - Gray/Blue',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 39.99},
#  {'product_id': 499,
#   'product_name': 'USB Type-C Digital AV Multiport Adapter',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 33.95},
#  {'product_id': 500,
#   'product_name': 'Samsung - 40 Class - LED - MU7000 Series - 2160p - Smart - 4K UHD TV with HDR"',
#   'brand_id': 1,
#   'category_id': 1,
#   'model_year': 2020,
#   'list_price': 551.99},
#  {'product_id': 501,
#   'product_name': 'Polk Audio - 7 3-Way Floor Speaker (Each) - Cherry"',
#   'brand_id': 21,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 79.72},
#  {'product_id': 502,
#   'product_name': 'BL2711U 27 16:9 4K UHD IPS Monitor',
#   'brand_id': 40,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 589.99},
#  {'product_id': 503,
#   'product_name': 'BL2711U 27 16:9 4K UHD IPS Monitor',
#   'brand_id': 40,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 609.0},
#  {'product_id': 504,
#   'product_name': 'Dell USB 3.0 Ultra HD/4K Triple Display Docking Station (D3100)',
#   'brand_id': 19,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 169.99},
#  {'product_id': 505,
#   'product_name': 'Definitive Technology - ProCinema 600 5.1-Channel Home Theater Speaker System - Black',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 1149.95},
#  {'product_id': 506,
#   'product_name': 'Definitive Technology - ProCinema 600 5.1-Channel Home Theater Speaker System - Black',
#   'brand_id': 33,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 521.99},
#  {'product_id': 507,
#   'product_name': '13.3 MacBook Air (Mid 2017, Silver)',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 979.0},
#  {'product_id': 508,
#   'product_name': 'CORSAIR M65 Pro RGB - FPS Gaming Mouse - 12',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 114.88},
#  {'product_id': 509,
#   'product_name': 'CORSAIR M65 Pro RGB - FPS Gaming Mouse - 12',
#   'brand_id': 6,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 59.99},
#  {'product_id': 510,
#   'product_name': 'Seagate - 2TB Internal SATA Hard Drive for Laptops',
#   'brand_id': 14,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 109.99},
#  {'product_id': 511,
#   'product_name': 'Details About Seagate Expansion 1tb External Usb 3.0 Portable Hard Drive Black',
#   'brand_id': 14,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 69.99},
#  {'product_id': 512,
#   'product_name': 'Liberate XLBT Bluetooth Headphones (Midnight)',
#   'brand_id': 20,
#   'category_id': 14,
#   'model_year': 2020,
#   'list_price': 169.2},
#  {'product_id': 513,
#   'product_name': 'Liberate XLBT Bluetooth Headphones (Midnight)',
#   'brand_id': 20,
#   'category_id': 14,
#   'model_year': 2020,
#   'list_price': 128.99},
#  {'product_id': 514,
#   'product_name': 'Apple - Pre-owned 9.7-inch iPad Pro - 32GB - Space gray',
#   'brand_id': 2,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 479.0},
#  {'product_id': 515,
#   'product_name': 'Logitech K800 Wireless Illuminated Keyboard — Backlit Keyboard',
#   'brand_id': 4,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 62.99},
#  {'product_id': 516,
#   'product_name': 'LG - Super-Multi 24x External USB 2.0 Double-Layer DVD±/CD-RW Drive - Black',
#   'brand_id': 15,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 39.99},
#  {'product_id': 517,
#   'product_name': 'Samsung Level U PRO Headphones with ANC, Black',
#   'brand_id': 1,
#   'category_id': 14,
#   'model_year': 2020,
#   'list_price': 99.99},
#  {'product_id': 518,
#   'product_name': 'JBL - 6 x 9" 3-Way Car Speakers with Polypropylene Cones (Pair) - Black"',
#   'brand_id': 7,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 79.99},
#  {'product_id': 519,
#   'product_name': 'JBL - 6 x 9" 3-Way Car Speakers with Polypropylene Cones (Pair) - Black"',
#   'brand_id': 7,
#   'category_id': 5,
#   'model_year': 2020,
#   'list_price': 64.99},
#  {'product_id': 520,
#   'product_name': 'HP - ProBook 14 Laptop - Intel Core i5 - 4GB Memory - 500GB Hard Drive - Black"',
#   'brand_id': 39,
#   'category_id': 4,
#   'model_year': 2020,
#   'list_price': 899.09}]

# %%
df_prod2 = df_prod.to_dict('records')

# %%
for v in df_prod2:
    print(v)

# %%
for v in df_prod2:
    print(v['product_id'], v['list_price'])
# Out:
# 1 23.99
# 2 136.99
# 3 599.0
# 4 151.99
# 5 199.99
# 6 89.95
# 7 59.99
# 8 99.99
# 9 121.99
# 10 174.99
# 11 29.99
# 12 499.99
# 13 99.99
# 14 249.99
# 15 67.99
# 16 599.0
# 17 11.99
# 18 24.99
# 19 99.99
# 20 249.99
# 21 799.98
# 22 23.99
# 23 149.99
# 24 89.99
# 25 139.99
# 26 199.99
# 27 98.95
# 28 79.99
# 29 398.0
# 30 11.79
# 31 142.99
# 32 74.99
# 33 199.99
# 34 239.0
# 35 248.0
# 36 199.99
# 37 199.99
# 38 349.99
# 39 148.0
# 40 99.99
# 41 323.52
# 42 99.99
# 43 68.75
# 44 449.99
# 45 919.99
# 46 195.99
# 47 399.98
# 48 299.87
# 49 65.89
# 50 34.99
# 51 79.99
# 52 224.99
# 53 249.98
# 54 324.99
# 55 89.99
# 56 349.99
# 57 179.99
# 58 617.99
# 59 799.99
# 60 79.99
# 61 82.99
# 62 39.99
# 63 54.99
# 64 2299.99
# 65 219.99
# 66 599.95
# 67 449.98
# 68 849.99
# 69 54.99
# 70 124.95
# 71 29.99
# 72 71.99
# 73 68.99
# 74 33.79
# 75 79.99
# 76 455.9
# 77 69.99
# 78 278.0
# 79 249.99
# 80 809.99
# 81 234.59
# 82 389.99
# 83 159.99
# 84 479.99
# 85 397.99
# 86 52.95
# 87 100.99
# 88 199.99
# 89 549.99
# 90 3989.99
# 91 799.98
# 92 199.99
# 93 118.99
# 94 349.99
# 95 349.99
# 96 99.99
# 97 112.99
# 98 20.99
# 99 249.99
# 100 4295.98
# 101 149.95
# 102 264.99
# 103 129.99
# 104 349.99
# 105 129.95
# 106 303.99
# 107 47.95
# 108 27.99
# 109 49.99
# 110 54.99
# 111 49.99
# 112 199.99
# 113 129.95
# 114 499.0
# 115 149.98
# 116 1449.0
# 117 359.99
# 118 2199.98
# 119 87.99
# 120 449.99
# 121 429.99
# 122 83.99
# 123 99.99
# 124 1597.99
# 125 76.99
# 126 329.99
# 127 54.0
# 128 249.99
# 129 203.99
# 130 499.95
# 131 429.99
# 132 48.99
# 133 2998.0
# 134 149.99
# 135 199.99
# 136 58.99
# 137 49.99
# 138 1269.99
# 139 169.0
# 140 1503.99
# 141 98.99
# 142 439.99
# 143 284.99
# 144 979.99
# 145 59.0
# 146 116.64
# 147 1599.52
# 148 139.99
# 149 229.99
# 150 179.99
# 151 319.99
# 152 234.99
# 153 64.99
# 154 1399.98
# 155 249.99
# 156 69.99
# 157 459.98
# 158 110.99
# 159 117.6
# 160 573.99
# 161 1999.99
# 162 179.99
# 163 390.99
# 164 81.99
# 165 29.95
# 166 1199.98
# 167 79.98
# 168 232.99
# 169 2799.99
# 170 249.98
# 171 1399.98
# 172 48.99
# 173 549.0
# 174 51.99
# 175 29.85
# 176 234.99
# 177 155.47
# 178 199.99
# 179 359.99
# 180 3137.95
# 181 79.0
# 182 165.99
# 183 178.0
# 184 1949.52
# 185 143.99
# 186 2498.0
# 187 179.99
# 188 499.98
# 189 169.99
# 190 140.45
# 191 99.99
# 192 249.99
# 193 138.19
# 194 189.99
# 195 72.99
# 196 799.98
# 197 161.99
# 198 199.99
# 199 75.99
# 200 58.99
# 201 33.49
# 202 219.99
# 203 79.99
# 204 23.99
# 205 399.0
# 206 598.0
# 207 69.98
# 208 322.99
# 209 43.96
# 210 99.99
# 211 749.0
# 212 2.0
# 213 83.31
# 214 159.99
# 215 59.99
# 216 149.99
# 217 22.06
# 218 7.99
# 219 149.99
# 220 99.99
# 221 307.99
# 222 899.98
# 223 349.99
# 224 271.99
# 225 199.99
# 226 169.99
# 227 399.98
# 228 1250.59
# 229 169.99
# 230 2197.99
# 231 89.0
# 232 33.99
# 233 431.99
# 234 174.99
# 235 24.99
# 236 328.0
# 237 69.0
# 238 78.99
# 239 48.99
# 240 394.99
# 241 99.99
# 242 34.99
# 243 112.99
# 244 64.95
# 245 322.99
# 246 181.99
# 247 89.95
# 248 2799.99
# 249 209.99
# 250 751.99
# 251 99.99
# 252 299.99
# 253 25.99
# 254 1499.98
# 255 199.99
# 256 50.5
# 257 65.0
# 258 49.93
# 259 2197.99
# 260 161.99
# 261 53.05
# 262 66.17
# 263 349.95
# 264 199.99
# 265 299.99
# 266 116.99
# 267 66.99
# 268 39.99
# 269 699.98
# 270 89.95
# 271 253.99
# 272 99.99
# 273 179.98
# 274 147.96
# 275 199.95
# 276 349.99
# 277 249.99
# 278 339.99
# 279 1199.98
# 280 3799.99
# 281 149.99
# 282 149.99
# 283 69.0
# 284 64.95
# 285 189.99
# 286 349.99
# 287 1045.99
# 288 983.99
# 289 2399.98
# 290 249.99
# 291 798.0
# 292 249.99
# 293 999.99
# 294 199.99
# 295 169.95
# 296 248.99
# 297 79.99
# 298 122.43
# 299 1744.99
# 300 69.0
# 301 1099.0
# 302 34.58
# 303 999.99
# 304 1799.99
# 305 199.99
# 306 99.99
# 307 45.99
# 308 1699.99
# 309 749.0
# 310 279.0
# 311 99.99
# 312 114.99
# 313 389.99
# 314 3013.98
# 315 99.99
# 316 2397.99
# 317 359.99
# 318 2199.99
# 319 22.08
# 320 84.99
# 321 184.0
# 322 289.98
# 323 59.99
# 324 1691.99
# 325 349.99
# 326 599.99
# 327 249.99
# 328 109.99
# 329 41.35
# 330 52.52
# 331 349.99
# 332 129.99
# 333 449.0
# 334 69.0
# 335 229.99
# 336 1299.99
# 337 349.99
# 338 199.99
# 339 289.98
# 340 72.0
# 341 540.57
# 342 349.99
# 343 75.11
# 344 99.99
# 345 71.26
# 346 249.0
# 347 54.39
# 348 3499.99
# 349 12.49
# 350 764.99
# 351 19.99
# 352 89.99
# 353 549.99
# 354 132.5
# 355 149.99
# 356 108.49
# 357 799.99
# 358 59.95
# 359 1.0
# 360 279.99
# 361 77.99
# 362 74.0
# 363 134.99
# 364 170.71
# 365 114.5
# 366 219.95
# 367 79.99
# 368 1.0
# 369 199.99
# 370 28.88
# 371 3.0
# 372 79.99
# 373 78.45
# 374 2.0
# 375 370.75
# 376 1.0
# 377 56.99
# 378 84.99
# 379 306.76
# 380 199.99
# 381 129.88
# 382 149.99
# 383 169.99
# 384 799.99
# 385 29.99
# 386 179.99
# 387 48.99
# 388 52.99
# 389 179.95
# 390 189.99
# 391 190.99
# 392 131.7
# 393 82.47
# 394 259.54
# 395 179.95
# 396 629.0
# 397 467.99
# 398 60.13
# 399 67.99
# 400 97.13
# 401 105.94
# 402 69.91
# 403 999.0
# 404 149.99
# 405 119.99
# 406 58.0
# 407 843.49
# 408 191.99
# 409 144.98
# 410 93.01
# 411 104.99
# 412 319.99
# 413 239.99
# 414 164.99
# 415 51.99
# 416 179.99
# 417 849.75
# 418 199.99
# 419 50.0
# 420 146.99
# 421 199.99
# 422 149.99
# 423 446.99
# 424 2499.0
# 425 77.29
# 426 355.72
# 427 187.47
# 428 105.98
# 429 173.98
# 430 359.99
# 431 90.55
# 432 1099.99
# 433 149.0
# 434 75.99
# 435 599.95
# 436 429.99
# 437 39.99
# 438 1279.99
# 439 81.89
# 440 16999.95
# 441 78.0
# 442 898.0
# 443 79.99
# 444 644.52
# 445 103.89
# 446 99.99
# 447 414.0
# 448 809.99
# 449 76.99
# 450 1499.99
# 451 119.99
# 452 125.0
# 453 2379.0
# 454 119.66
# 455 16.91
# 456 999.99
# 457 199.99
# 458 799.99
# 459 699.99
# 460 799.95
# 461 94.99
# 462 1299.0
# 463 999.0
# 464 3298.0
# 465 197.99
# 466 1972.59
# 467 121.28
# 468 29.95
# 469 339.95
# 470 576.99
# 471 59.99
# 472 52.99
# 473 49.99
# 474 687.0
# 475 216.22
# 476 293.99
# 477 1599.98
# 478 83.2
# 479 10.99
# 480 69.85
# 481 55.95
# 482 78.99
# 483 349.99
# 484 39.99
# 485 66.46
# 486 619.99
# 487 650.99
# 488 4275.0
# 489 248.0
# 490 171.98
# 491 799.97
# 492 69.0
# 493 2115.99
# 494 4296.99
# 495 199.99
# 496 2495.0
# 497 41.98
# 498 39.99
# 499 33.95
# 500 551.99
# 501 79.72
# 502 589.99
# 503 609.0
# 504 169.99
# 505 1149.95
# 506 521.99
# 507 979.0
# 508 114.88
# 509 59.99
# 510 109.99
# 511 69.99
# 512 169.2
# 513 128.99
# 514 479.0
# 515 62.99
# 516 39.99
# 517 99.99
# 518 79.99
# 519 64.99
# 520 899.09

# %%
sql = 'INSERT product_new1 VALUES(?,?,?,?,?,?)'

# %%
for v in df_prod2:
    crs.execute(sql, (v['product_id'], v['product_name'], v['brand_id'], v['category_id'], v['model_year'], v['list_price']))

# %% [markdown]
# #### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Using SQLAlchemy</p>
#
# <a id="6.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue><font color=red>SQLAlchemy</font> is an open-source SQL toolkit and Object-Relational Mapping (ORM) library for Python programming language. It provides a set of high-level API (Application Programming Interface) for interacting with relational databases, allowing developers to work with databases using Python objects and methods rather than raw SQL queries.</font>

# %%
#pip install SQLAlchemy

# %%
from sqlalchemy import create_engine
from sqlalchemy import text
# Out:
# '2.0.23'

# %%
#  Creating engine for MS SQL Server

server = 'localhost'
dbname = 'TestA' # The database name you want to work.
driver = 'ODBC+Driver+17+for+SQL+Server'

engine = create_engine(f'mssql+pyodbc://{server}/{dbname}?trusted_connection=yes&driver={driver}')

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# - <font color=darkblue>Begin by creating a connection. Then, use Pandas' <font color=red>to_sql</font> method to send the dataframe to SQL Server as a table.
#
# <span style="display:inline-block;background-color:#5bc0de;color:#fff;border-radius:100%;padding:2px 6px;font-size:18px;line-height:1;">i</span> <font color=darkpink>When performing this operation with SQLAlchemy, there is no need to create an empty table or perform an insert operation.</font>

# %%
df_prod.to_sql('product_new2', engine, 'dbo', index=False, if_exists='fail') # replace or append can be used
# Out:
# 171
